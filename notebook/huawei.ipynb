# %% [markdown]
# <a href="https://colab.research.google.com/github/wqw547243068/Python-learning/blob/master/data_mining/huawei.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 华为任正非讲话挖掘分析
# - 大数据文摘：[卅年春秋，谁主沉浮？从400篇任正非演讲稿分析中，一探华为
# ](https://mp.weixin.qq.com/s?__biz=MjM5MTQzNzU2NA==&mid=2651670909&idx=1&sn=d690d8efa7237594312c6ee7c3741312&chksm=bd4c6eee8a3be7f8f39240a6c4fd1d04f26dfb0a9af6644e1d5acd13974d0b5d2e79f025c33b&mpshare=1&scene=23&srcid=#rd)
# - ![](https://inews.gtimg.com/newsapp_bt/0/9091216116/641)
# - 分析结果[展示](https://wqw547243068.github.io/Python-learning/data_mining/huawei)
# - ![](http://pic.caixin.com/blog/Mon_1905/m_1558778021_IcqBAS.png)
# ## 目标
# - 词频统计：
#    - 1.词频排名（选取Top10）
#    - 2.生成词云：以Top500的词汇为基础
#    - 3.美国、苹果、三星出现的次数
#    - 4.三个阶段的词频排名（分别是 95年-03年，04年-2012年，2012年-2019年）
# - 文本相似度分析：任正非和胸怀、创新、格局、领导力的相似度
# - 还可以加一个每年发表声明字数，看看媒体曝光量

# %% [markdown]
# ## 数据准备
# - 从[github](https://github.com/benmahr/RenZhengfei)上下载任正非的历次讲话稿
# - 时间范围：1994-2018

# %%
# !ls
# Out:
# sample_data

# %%
#!git clone https://github.com/benmahr/RenZhengfei.git
#[2019-06-20]由于原repo里的数据被删除，更新地址
# !wget https://github.com/wqw547243068/Python-learning/raw/master/data_mining/RenZhengfei.zip
# !unzip RenZhengfei
# !ls RenZhengfei
# Out:
# --2019-06-20 02:35:28--  https://github.com/wqw547243068/Python-learning/raw/master/data_mining/RenZhengfei.zip
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/wqw547243068/Python-learning/master/data_mining/RenZhengfei.zip [following]
# --2019-06-20 02:35:28--  https://raw.githubusercontent.com/wqw547243068/Python-learning/master/data_mining/RenZhengfei.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2297223 (2.2M) [application/zip]
# Saving to: ‘RenZhengfei.zip.1’
#
# RenZhengfei.zip.1   100%[===================>]   2.19M  --.-KB/s    in 0.05s
#
# 2019-06-20 02:35:28 (42.1 MB/s) - ‘RenZhengfei.zip.1’ saved [2297223/2297223]
#
# Archive:  RenZhengfei.zip
#    creating: RenZhengfei/
#    creating: RenZhengfei/1994/
#   inflating: RenZhengfei/1994/19940118_赴美考察散记.md
#   inflating: RenZhengfei/1994/19940126_团结奋斗_再创华为佳绩.md
#   inflating: RenZhengfei/1994/19940605_胜利祝酒辞.md
#   inflating: RenZhengfei/1994/19940621_对中国农话网与交换机产业的一点看法.md
#   inflating: RenZhengfei/1994/19941225_从二则空难事故看员工培训的重要性.md
#   inflating: RenZhengfei/1994/19941225_致新员工书.md
#    creating: RenZhengfei/1995/
#   inflating: RenZhengfei/1995/19950109_坚定不移地坚持发展的方向.md
#   inflating: RenZhengfei/1995/19950110_不前进就免职.md
#   inflating: RenZhengfei/1995/19950110_励精图治，再创辉煌.md
#   inflating: RenZhengfei/1995/19950110_英雄好汉站出来.md
#   inflating: RenZhengfei/1995/19950618_上海电话信息技术和业务管理研讨会致谢词.md
#   inflating: RenZhengfei/1997/1997_苦练基本功，争做维护专家.md
#    creating: RenZhengfei/1998/
#   inflating: RenZhengfei/1998/19980116_狭路相逢勇者生.md
#   inflating: RenZhengfei/1998/1998012_不做昙花一现的英雄.md
#   inflating: RenZhengfei/1998/19980220_我们向美国人民学习什么.md
#   inflating: RenZhengfei/1998/19980328_要从必然王国，走向自由王国.md
#   inflating: RenZhengfei/1998/199803_华为基本法.md
#   inflating: RenZhengfei/1998/199803_在自我批判中进步.md
#   inflating: RenZhengfei/1998/199805_希望寄托在你们身上.md
#   inflating: RenZhengfei/1998/19980620_华为的红旗到底能打多久.md
#   inflating: RenZhengfei/1998/19980716_小改进、大奖励.md
#   inflating: RenZhengfei/1998/199809_全心全意对产品负责全心全意为客户服务.md
#   inflating: RenZhengfei/1998/19981209_印度随笔.md
#  extracting: RenZhengfei/1998/1998_把生命注入到产品中去.md
#    creating: RenZhengfei/1999/
#   inflating: RenZhengfei/1999/19990208_创业创新必须以提升企业核心竞争力为中心.md
#   inflating: RenZhengfei/1999/19990417_在IPD动员大会上的讲话.md
#   inflating: RenZhengfei/1999/199904_在实践中培养和选拔干部.md
#   inflating: RenZhengfei/1999/19990520_“中国人今天说不”图片新闻感想.md
#   inflating: RenZhengfei/1999/19990520_能工巧匠是我们企业的宝贵财富.md
#   inflating: RenZhengfei/1999/19990720_任正非答新员工问.md
#    creating: RenZhengfei/2000/
#   inflating: RenZhengfei/2000/20000114_与身处逆境员工的对话录.md
#   inflating: RenZhengfei/2000/20000128_凤凰展翅再创辉煌.md
#   inflating: RenZhengfei/2000/20000320_一个职业管理者的责任和使命.md
#   inflating: RenZhengfei/2000/20000408_活下去，是企业的硬道理.md
#   inflating: RenZhengfei/2000/20000717_沟通从心灵开始.md
#   inflating: RenZhengfei/2000/20000720_创新是华为发展的不竭动力.md
#   inflating: RenZhengfei/2000/20000901_为什么要自我批判.md
#   inflating: RenZhengfei/2000/2000_任正非在秘书资格颁证大会上的讲话.md
#    creating: RenZhengfei/2001/
#   inflating: RenZhengfei/2001/20010118_雄赳赳气昂昂跨过太平洋.md
#   inflating: RenZhengfei/2001/20010201_华为的冬天.md
#   inflating: RenZhengfei/2001/20010208_我的父亲母亲.md
#   inflating: RenZhengfei/2001/20010424_北国之春.md
#    creating: RenZhengfei/2002/
#   inflating: RenZhengfei/2002/2002_迎接挑战，苦练内功，迎接春天的到来.md
#    creating: RenZhengfei/2003/
#   inflating: RenZhengfei/2003/20030525_在理性与平实中存活.md
#   inflating: RenZhengfei/2003/20030526_产品发展的路标是客户需求导向企业管理的目标是流程化的组织建设.md
#   inflating: RenZhengfei/2003/2003_发挥核心团队作用，不断提高人均效益.md
#   inflating: RenZhengfei/2003/2003_在自我批判指导委员会座谈会上的讲话.md
#    creating: RenZhengfei/2004/
#   inflating: RenZhengfei/2004/20040115_持续提高人均效益建设高绩效企业文化.md
#   inflating: RenZhengfei/2004/20040428_华为公司的核心价值观.md
#    creating: RenZhengfei/2005/
#   inflating: RenZhengfei/2005/20050726_华为与对手做朋友海外不打价格战.md
#    creating: RenZhengfei/2006/
#   inflating: RenZhengfei/2006/20060430_全流程降低成本和费用提高盈利能力.md
#   inflating: RenZhengfei/2006/20060510_在华为收购港湾时的谈话纪要.md
#   inflating: RenZhengfei/2006/20060719_我的青春岁月.md
#   inflating: RenZhengfei/2006/20060721_天道酬勤.md
#   inflating: RenZhengfei/2006/200608_冰岛游记.md
#   inflating: RenZhengfei/2006/20060904_上甘岭是不会自然产生将军的但将军都曾经是英雄.md
#   inflating: RenZhengfei/2006/20061120_华为大学要成为将军的摇篮.md
#   inflating: RenZhengfei/2006/20061214_在BT系统部、英国代表处汇报会上的讲话.md
#   inflating: RenZhengfei/2006/20061218_实事求是的科研方向与二十年的艰苦努力.md
#    creating: RenZhengfei/2007/
#   inflating: RenZhengfei/2007/20070108_对区域监控工作的讲话纪要.md
#   inflating: RenZhengfei/2007/20070108_财经的变革是华为公司的变革，不是财务系统的变革.md
#   inflating: RenZhengfei/2007/200702_要快乐的度过充满困难的一生.md
#   inflating: RenZhengfei/2007/20070315_在行政采购及信息安全问题座谈会上的讲话.md
#   inflating: RenZhengfei/2007/20070409_听取艰苦地区生活专项问题汇报会上的讲话.md
#   inflating: RenZhengfei/2007/20070612_以生动活泼的方式传递奋斗者为主体的文化.md
#   inflating: RenZhengfei/2007/20070703_上甘岭在你心中，无论何时何地都可以产生英雄.md
#   inflating: RenZhengfei/2007/20070713_敢于胜利，才能善于胜利.md
#   inflating: RenZhengfei/2007/20070721_完善和提高对艰苦地区员工的保障措施.md
#   inflating: RenZhengfei/2007/20070803_关于员工培训工作的谈话.md
#   inflating: RenZhengfei/2007/20070808_变革最重要的问题是一定要落地.md
#   inflating: RenZhengfei/2007/20070824_内控体系建设就是要穿美国鞋，不打补丁.md
#   inflating: RenZhengfei/2007/20070914_将军如果不知道自己错在哪里，就永远不会成为将军.md
#    creating: RenZhengfei/2008/
#   inflating: RenZhengfei/2008/20070728_珍惜生命，要从自己关爱自己做起.md
#   inflating: RenZhengfei/2008/20080131_在EMT例会“08年公司业务计划与预算”汇报上的讲话.md
#   inflating: RenZhengfei/2008/20080215_看莫斯科保卫战有感.md
#   inflating: RenZhengfei/2008/20080410_人生是美好的，但过程确实是痛苦的.md
#   inflating: RenZhengfei/2008/20080531_让青春的火花，点燃无愧无悔的人生.md
#   inflating: RenZhengfei/2008/20080613_让青春的生命放射光芒.md
#   inflating: RenZhengfei/2008/20080616_大家都是共和国的英雄.md
#   inflating: RenZhengfei/2008/20080705_任正非在PSST体系干部大会上的讲话.md
#   inflating: RenZhengfei/2008/20080715_逐步加深理解“以客户为中心，以奋斗者为本”的企业文化.md
#   inflating: RenZhengfei/2008/20080721_在地区部向EMT进行2008年年中述职会议上的讲话.md
#   inflating: RenZhengfei/2008/200807_理解国家，做好自己.md
#   inflating: RenZhengfei/2008/20080902_从泥坑里爬起来的人就是圣人.md
#   inflating: RenZhengfei/2008/20080922_从汶川特大地震一片瓦砾中，一座百年前建的教堂不倒所想到的.md
#   inflating: RenZhengfei/2008/20081229_围绕客户PO打通，支撑“回款、收入、项目预核算”.md
#   inflating: RenZhengfei/2008/2008_2008年新年祝词.md
#    creating: RenZhengfei/2009/
#   inflating: RenZhengfei/2009/20090115_开放、妥协与灰度.md
#   inflating: RenZhengfei/2009/20090116_让听得见炮声的人来决策.md
#   inflating: RenZhengfei/2009/20090116_谁来呼唤炮火，如何及时提供炮火支援.md
#   inflating: RenZhengfei/2009/20090206_任正非与IFS项目组及财经体系员工座谈纪要.md
#   inflating: RenZhengfei/2009/20090312_在驻外行政人员培训交流沟通会上的座谈纪要.md
#   inflating: RenZhengfei/2009/20090324_市场经济是最好的竞争方式，经济全球化是不可阻挡的潮流.md
#   inflating: RenZhengfei/2009/20090327_任正非与PMS高端项目经理的座谈纪要.md
#   inflating: RenZhengfei/2009/20090424_深淘滩，低作堰.md
#   inflating: RenZhengfei/2009/20090827_具有“长期持续艰苦奋斗的牺牲精神，永恒不变的艰苦奋斗的工作作风”是成为一个将军最基本条件.md
#   inflating: RenZhengfei/2009/20091026_CFO要走向流程化和职业化，支撑公司及时、准确、优质、低成本交付.md
#   inflating: RenZhengfei/2009/20091127_加快CFO队伍建设，支撑IFS推行落地.md
#    creating: RenZhengfei/2010/
#   inflating: RenZhengfei/2010/2000_以客户为中心，加大平台投入，开放合作，实现共赢.md
#   inflating: RenZhengfei/2010/20091231_春风送暖入屠苏.md
#   inflating: RenZhengfei/2010/20100120_以客户为中心，以奋斗者为本，长期坚持艰苦奋斗是我们胜利之本.md
#   inflating: RenZhengfei/2010/20100304_在全球行政人员年度表彰暨经验交流大会座谈纪要.md
#   inflating: RenZhengfei/2010/20100430_拉通项目四算，支撑项目层面经营管理.md
#   inflating: RenZhengfei/2010/20100715_干部要担负起公司价值观的传承.md
#   inflating: RenZhengfei/2010/20100910_开放、合作、自我批判，做容千万家的天下英雄.md
#   inflating: RenZhengfei/2010/20101031_世博结束了，我们胜利了.md
#   inflating: RenZhengfei/2010/20101125z_改善和媒体的关系.md
#   inflating: RenZhengfei/2010/20101203_做事要霸气，做人要谦卑，要按消费品的规律，敢于追求最大的增长和胜利.md
#   inflating: RenZhengfei/2010/20101206_五彩云霞飞遍天涯.md
#   inflating: RenZhengfei/2010/20110104_以“选拔制”建设干部队伍，按流程梳理和精简组织，推进组织公开性和均衡性建设.md
#    creating: RenZhengfei/2011/
#   inflating: RenZhengfei/2011/20110117_成功不是未来前进的可靠向导.md
#   inflating: RenZhengfei/2011/20110223_关于珍爱生命与职业责任的讲话.md
#   inflating: RenZhengfei/2011/20110414_华为关于如何与奋斗者分享利益的座谈会纪要.md
#   inflating: RenZhengfei/2011/20110614_任总与罗马尼亚账务共享中心座谈会纪要.md
#   inflating: RenZhengfei/2011/20110727_与华为大学第10期干部高级管理研讨班学员座谈纪要.md
#   inflating: RenZhengfei/2011/20111019_任正非与财经体系员工座谈讲话.md
#   inflating: RenZhengfei/2011/20111026_与同等学历认证班学员座谈纪要.md
#   inflating: RenZhengfei/2011/20111031_力出一孔，要集中优势资源投入在主航道上，敢于去争取更大的机会与差距.md
#   inflating: RenZhengfei/2011/20111225_一江春水向东流.md
#    creating: RenZhengfei/2012/
#   inflating: RenZhengfei/2012/20120119_不要盲目扩张，不要自以为已经强大.md
#   inflating: RenZhengfei/2012/20120319_绝对考核的目的是团结多数人.md
#   inflating: RenZhengfei/2012/20120412_紧紧围绕客户，在战略层面宣传公司.md
#   inflating: RenZhengfei/2012/20120423_董事会领导下的CEO轮值制度辨.md
#   inflating: RenZhengfei/2012/20120712_中国没有创新土壤不开放就是死亡.md
#   inflating: RenZhengfei/2012/201209_面向未来，以客户痛点为切入点，全球化展示.md
#   inflating: RenZhengfei/2012/20121115_东南非多国管理部向任总汇报工作纪要.md
#   inflating: RenZhengfei/2012/20121120_与毛里求斯员工座谈会议纪要.md
#   inflating: RenZhengfei/2012/20121219_与华为大学教育学院座谈会纪要.md
#    creating: RenZhengfei/2013/
#   inflating: RenZhengfei/2013/20121231_力出一孔，利出一孔.md
#   inflating: RenZhengfei/2013/20130114_在小国表彰会上的讲话.md
#   inflating: RenZhengfei/2013/20130219_任总和广州代表处座谈纪要.md
#   inflating: RenZhengfei/2013/20130330_家人永远不接班.md
#   inflating: RenZhengfei/2013/20130517_要敢于超越美国公司，最多就是输.md
#   inflating: RenZhengfei/2013/20130527_在海外行政后勤服务管理思路汇报会上的讲话.md
#   inflating: RenZhengfei/2013/20130627_财经流程建设向任总汇报纪要.md
#   inflating: RenZhengfei/2013/20130719_要培养一支能打仗、打胜仗的队伍.md
#   inflating: RenZhengfei/2013/20130723_在重装旅集训营座谈会上的讲话.md
#   inflating: RenZhengfei/2013/20130904_在GTS客户培训服务座谈会上的讲话.md
#   inflating: RenZhengfei/2013/20130905_最好的防御就是进攻.md
#   inflating: RenZhengfei/2013/20130911_团结一切可以团结的力量.md
#   inflating: RenZhengfei/2013/20130911_提倡节俭办晚会，节约会议成本.md
#   inflating: RenZhengfei/2013/20130929_财经向任正非汇报纪要.md
#   inflating: RenZhengfei/2013/20131019_用乌龟精神，追上龙飞船.md
#   inflating: RenZhengfei/2013/20131031_与CEC成员座谈会的讲话.md
#   inflating: RenZhengfei/2013/20131105_在GTS网规网优业务座谈会上的讲话.md
#   inflating: RenZhengfei/2013/20131106_在华为大学教育学院工作汇报会上的讲话.md
#   inflating: RenZhengfei/2013/20131111_在IP交付保障团队座谈会上的讲话.md
#   inflating: RenZhengfei/2013/20131125_我一贯不是一个低调的人.md
#   inflating: RenZhengfei/2013/20131129_在EMT办公例会上的讲话.md
#   inflating: RenZhengfei/2013/20131204_在公司内控与风险管理“三层防线”优化方案汇报的讲话.md
#   inflating: RenZhengfei/2013/20131219_关于“严格、有序、简化的认真管理是实现超越的关键”的座谈纪要.md
#   inflating: RenZhengfei/2013/20131222_聚焦商业成功，英雄不问出处.md
#   inflating: RenZhengfei/2013/20131228在运营商网络BG战略务虚会上的讲话及主要讨论发言.md
#   inflating: RenZhengfei/2013/20131230_任正非在大规模消灭腐败进展汇报会上的讲话.md
�报会上的讲话.md
#   inflating: RenZhengfei/2014/20141106_遍地英雄下夕烟，六亿神州尽舜尧.md
#   inflating: RenZhengfei/2014/20141114_坚持为世界创造价值，为价值而创新.md
#   inflating: RenZhengfei/2014/20141205_在“从中心仓到站点打通”工作汇报会上的讲话.md
#   inflating: RenZhengfei/2014/20141218_依托欧美先进软件包构建高质量的IT系统.md
#   inflating: RenZhengfei/2014/20141218在艰苦地区及岗位管理部工作汇报会上的讲话.md
#    creating: RenZhengfei/2015/
#   inflating: RenZhengfei/2015/20150108_在与法务部、董秘及无线员工座谈会上的讲话.md
#   inflating: RenZhengfei/2015/20150109_打造运营商BG“三朵云”，将一线武装到牙齿.md
#   inflating: RenZhengfei/2015/20150116_变革的目的就是要多产粮食和增加土地肥力.md
#   inflating: RenZhengfei/2015/20150125_最大的敌人是我们自己.md
#   inflating: RenZhengfei/2015/20150127_改善艰苦地区条件，加快循环赋能，为公司筑起第二道防线.md
#   inflating: RenZhengfei/2015/20150310_非主航道组织要率先实现流程责任制，通过流程责任来选拔管理者，淘汰不作为员工，为公司管理进步摸索经验.md
#   inflating: RenZhengfei/2015/20150318_在2015年全球行政工作年会上的讲话.md
#   inflating: RenZhengfei/2015/20150331_在变革战略预备队进展汇报上的讲话.md
#   inflating: RenZhengfei/2015/20150408_埃森哲董事长Pierre拜访任正非的会谈纪要.md
#   inflating: RenZhengfei/2015/20150504_在变革战略预备队及进展汇报座谈上的讲话.md
#   inflating: RenZhengfei/2015/20150506_与BCG顾问交流会谈纪要.md
#   inflating: RenZhengfei/2015/20150508_在变革战略预备队誓师及颁奖典礼上的座谈纪要.md
#   inflating: RenZhengfei/2015/20150515_在监管重装旅座谈会上的讲话.md
#   inflating: RenZhengfei/2015/20150520_在公司质量工作汇报会上的讲话.md
#   inflating: RenZhengfei/2015/20150702_在固网产业趋势及进展汇报会上的讲话.md
#   inflating: RenZhengfei/2015/20150713_在合同场景师建设思路汇报上的讲话.md
#   inflating: RenZhengfei/2015/20150713_在子公司监督型董事会管理层监督方案及试点情况汇报上的讲话.md
#   inflating: RenZhengfei/2015/20150714_与英国研究所、北京研究所、伦敦财经风险管控中心座谈的纪要.md
#   inflating: RenZhengfei/2015/20150730_在战略预备队业务汇报上的讲话.md
#   inflating: RenZhengfei/2015/20150731_在变革战略预备队第三期誓师典礼上的讲话.md
#   inflating: RenZhengfei/2015/20150812_构建先进装备，沉淀核心能力，在更高维度打赢下一场战争.md
#   inflating: RenZhengfei/2015/20150827_脚踏实地，做挑战自我的长跑者.md
#   inflating: RenZhengfei/2015/20150828_在2015年8月28日EMT办公会议上的讲话.md
#   inflating: RenZhengfei/2015/20150902_在波士顿咨询汇报行政服务变革（国家驻点成果及未来变革方向）的讲话.md
#   inflating: RenZhengfei/2015/20150906_任正非接受福布斯中文网采访.md
#   inflating: RenZhengfei/2015/20150907_在战略预备队誓师典礼暨优秀队员表彰大会上的讲话.md
#   inflating: RenZhengfei/2015/20150923_在公共及政府事务部2015年工作汇报会的讲话.md
#   inflating: RenZhengfei/2015/20150924_在2015年9月24日EMT办公会议上的讲话.md
#   inflating: RenZhengfei/2015/20150928_在GTS站点信息库、地理信息库、网络动态运行信息库和集成交付平台建设汇报会上的讲话.md
#   inflating: RenZhengfei/2015/201509致新员工书.md
#   inflating: RenZhengfei/2015/20151010_最终的竞争是质量的竞争.md
#   inflating: RenZhengfei/2015/20151023_在调查工作授权及流程优化汇报上的讲话.md
#   inflating: RenZhengfei/2018/20180321_研发要做智能世界的“发动机”.md
#   inflating: RenZhengfei/2018/20180411_在黎巴嫩代表处的讲话.md
#   inflating: RenZhengfei/2018/20180420_关于人力资源组织运作优化的讲话.md
#   inflating: RenZhengfei/2018/20180426_任正非在战略预备队述职会上的讲话.md
#   inflating: RenZhengfei/2018/20180515_励精图治，十年振兴.md
#   inflating: RenZhengfei/2018/20180605_在剑桥和伊普斯维奇研究所座谈纪要.md
#   inflating: RenZhengfei/2018/20180622_BG机关要缩短经线，畅通纬线，强化作战组织的能力考核与选拔，精减非作战组织的规模及运作.md
#   inflating: RenZhengfei/2018/20180623_在2018年IRB战略务虚研讨会的讲话.md
#   inflating: RenZhengfei/2018/20180627_与平台协调委员会座谈纪要.md
#   inflating: RenZhengfei/2018/20180701在卢旺达饭店与员工聊天记录.md
#   inflating: RenZhengfei/2018/20180713_在攀登珠峰的路上沿途下蛋.md
#   inflating: RenZhengfei/2018/20180718在GTS人工智能实践进展汇报会上的讲话.md
#   inflating: RenZhengfei/2018/20180929_从人类文明的结晶中，找到解决世界问题的钥匙.md
#   inflating: RenZhengfei/2018/20181017_坚持多路径、多梯次、多场景化的研发路线，攻上“上甘岭”，实现5G战略领先.md
#   inflating: RenZhengfei/2018/20181019_鼓足干劲，力争上游，不畏一切艰苦困苦.md
#   inflating: RenZhengfei/2018/20181107_寂寞的英雄是伟大的英雄，我们要鼓励新旧循环.md
#   inflating: RenZhengfei/2018/20181119_加强与国内大学合作，吸纳全球优秀人才，共同推动中国基础研究.md
#   inflating: RenZhengfei/2018/20181121_任正非在日本研究所业务汇报.md
#   inflating: RenZhengfei/R&D.md
#   inflating: RenZhengfei/README.md
#   inflating: RenZhengfei/SUMMARY.md
#  1994   1997   2000   2003   2006   2009   2012   2015	 2018	     SUMMARY.md
#  1995   1998   2001   2004   2007   2010   2013   2016	'R&D.md'
#  1996   1999   2002   2005   2008   2011   2014   2017	 README.md

# %%
ls RenZhengfei/2010
# Out:
# 2000_以客户为中心，加大平台投入，开放合作，实现共赢.md
# 20091231_春风送暖入屠苏.md
# 20100120_以客户为中心，以奋斗者为本，长期坚持艰苦奋斗是我们胜利之本.md
# 20100304_在全球行政人员年度表彰暨经验交流大会座谈纪要.md
# 20100430_拉通项目四算，支撑项目层面经营管理.md
# 20100715_干部要担负起公司价值观的传承.md
# 20100910_开放、合作、自我批判，做容千万家的天下英雄.md
# 20101031_世博结束了，我们胜利了.md
# 20101125z_改善和媒体的关系.md
# 20101203_做事要霸气，做人要谦卑，要按消费品的规律，敢于追求最大的增长和胜利.md
# 20101206_五彩云霞飞遍天涯.md
# 20110104_以“选拔制”建设干部队伍，按流程梳理和精简组织，推进组织公开性和均衡性建设.md

# %%
s='a'
type(s)
# Out:
# str

# %%
import os
import sys
import jieba
from jieba import analyse
import json

data_dir = 'RenZhengfei'
# 存储文件、目录类型的数据
data_dict = {'dir':{'list':[], 'title':{}}, 
             'file':{'list':[]},
             'word_list':[],
             'word_dict':{},
            }
def get_keywords(name):
    """
        分词、分句
    """
    word_dict = {}
    speak_list = []
    def extract_kw(w):
        #seg_list = jieba.cut(text)
        #res = analyse.TFIDF(w) # tf-idf提取关键词
        res = analyse.extract_tags(w)
        #res = analyse.textrank(w) # text-rank提取关键词
        return res
    if type(name) == str:
        # 直接对文本提取关键词
        speak_list.append(name)
        #extract_kw(name)
    elif type(name) == list:
        # 文件列表
        speak_list = name
        
    else:
        print('输入数据类型异常: {}'.format(name))
        return word_dict
    for w in speak_list:
        # 提取关键词
        for word in res:
            word_dict[word] = word_dict.get(word, 0) + 1

# 读取文本文件
for d in os.listdir(data_dir):
    if d.startswith('.'):
        # 过滤隐藏文件
        continue
    p = os.path.join(data_dir, d) 
    # 筛选指定目录
    if os.path.isdir(p):
        if not d.isnumeric():
            #过滤非数字目录
            print('过滤目录: {}'.format(d))
            continue
        data_dict['dir']['list'].append(d)
        data_dict['dir']['title'][d] = os.listdir(p)
        #print('目录: ',p)
    elif os.path.isfile(p):
        print('文件: ',p)
        data_dict['file']['list'].append(d)
    else:
        print('其他：',p, type(p))
print(json.dumps(data_dict, indent=2, ensure_ascii=False))
# Out:
# 文件:  RenZhengfei/R&D.md
# 文件:  RenZhengfei/README.md
# 文件:  RenZhengfei/SUMMARY.md
# {
#   "dir": {
#     "list": [
#       "1995",
#       "2017",
#       "2015",
#       "2008",
#       "2001",
#       "1996",
#       "2007",
#       "2012",
#       "2014",
#       "2018",
#       "2004",
#       "2005",
#       "2016",
#       "2011",
#       "2009",
#       "2003",
#       "1999",
#       "2013",
#       "2006",
#       "1998",
#       "2000",
#       "1994",
#       "2002",
#       "1997",
#       "2010"
#     ],
#     "title": {
#       "1995": [
#         "19950110_不前进就免职.md",
#         "19951226_目前我们的形势和任务.md",
#         "199507_要建立一个均衡的平台.md",
#         "19950110_英雄好汉站出来.md",
#         "19951118_解放思想，迎接96年市场大战.md",
#         "19951116_在第四届国际电子通信展华为庆祝酒会的发言.md",
#         "19950110_励精图治，再创辉煌.md",
#         "19950109_坚定不移地坚持发展的方向.md",
#         "19950618_上海电话信息技术和业务管理研讨会致谢词.md"
#       ],
#       "2017": [
#         "20170117_在消费者BG年度大会上的讲话.md",
#         "20171024_在消费者BG业务汇报及骨干座谈会上的讲话.md",
#         "20170824_与采购干部座谈会上的讲话.md",
#         "20170913_任总在伦敦FRCC听取贸易合规和金融合规汇报的讲话.md",
#         "20171218_在落实日落法及清理机关说NO.md",
#         "20170427_在职员类定位与差异化管理汇报会上的讲话.md",
#         "20171006_一杯咖啡吸收宇宙能量，一桶浆糊粘接世界智慧.md",
#         "20170621_与任总在曼谷座谈纪要.md",
#         "20170622_与德国代表处交流纪要.md",
#         "20170821_在规范职能组织权力工作组座谈会上的讲话.md",
#         "20170527_在继任计划工作汇报会上的讲话.md",
#         "20170120_在健康指导中心业务变革项目阶段汇报会上的讲话.md",
#         "20170917_在捷克代表处讲话.md",
#         "20170205_在玻利维亚代表处的讲话.md",
#         "20170807_在行政服务解决“小鬼难缠”工作进展汇报上的讲话.md",
#         "20170712_在新员工入职培训座谈会上的讲话.md",
#         "20171113_关于人力资源管理纲要2.0修订与研讨的讲话纪要.md",
#         "20171213_什么是确定性工作.md",
#         "20171019_在2017年第四季度地区部总裁会议上的讲话.md",
#         "20170220_在泛网络区域组织变革优化总结与规划汇报的讲话.md",
#         "20170215_在泰国与地区部负责人、在尼泊尔与员工座谈的讲话.md",
#         "20170224_在高研班和战略预备队汇报会上的讲话.md",
#         "20170816_在冰岛与四位弟兄咖啡细语.md",
#         "20170314_我们的目的是实现高质量.md",
#         "20170316_客户需求导向，提升公司E2E系统竞争力.md",
#         "20170602_方向要大致正确，组织要充满活力.md",
#         "20170410_与网络能源产品线部分员工晚餐会的讲话.md",
#         "20170829_任总在GTS人工智能实践进展汇报会上的讲话.md",
#         "20170601_什么叫精神文明，什么叫物质文明.md",
#         "20170723_任正非与徐直军在消费者BG2017年中市场大会上的讲话.md",
#         "20170711_在战略预备队述职会上的讲话.md",
#         "20171225_在听取展厅工作汇报时，关于咨询师的讲话.md",
#         "20170406_与广州代表处部分员工晚餐会的讲话.md",
#         "20170906_在英国代表处的讲话.md",
#         "20170828_在诺亚方舟实验室使能工程部成立会上的讲话.md",
#         "20170206_在巴拉圭的讲话.md",
#         "20170826_开放创新，吸纳全球人才，构建“为我所知、为我所用、为我所有”的全球能力布局.md",
#         "20170705_在华为平安园区项目汇报会上的讲话.md",
#         "20170914_任总与接入网团队座谈会上的讲话.md",
#         "20170809_在子公司监督型董事会年中工作会议上的讲话.md",
#         "20171120_在公司愿景与使命研讨会上的讲话.md",
#         "20170107_在人工智能应用GTS研讨会上的讲话.md",
#         "20170829_在“合同在代表处审结”工作汇报会上的讲话.md",
#         "201704_在哈佛商学院全球高管论坛上的演讲.md",
#         "20170328_在支付系统员工座谈会上的讲话.md",
#         "20170424_在道德遵从委员会第二次代表大会的讲话.md",
#         "20170718_与韩国办事处交流纪要.md",
#         "20170807_科学的量化、简化管理，关注技能与经验的积累，培育工匠文化.md",
#         "20171219_熵减的过程是痛苦的，前途是光明的.md",
#         "20170624_在俄罗斯代表处讲话纪要.md",
#         "201701_在北部非洲（尼日尔、布基纳法索）汇报会议的讲话.md",
#         "20170418_在战略预备队座谈会上的讲话.md",
#         "20171003_在加拿大代表处的讲话.md",
#         "20170807_在人力资源管理纲要2.0沟通会上的讲话.md",
#         "20170327_在公司监督与管控体系延伸建设思考汇报会上的讲话.md",
#         "20171211_什么是“一杯咖啡吸收宇宙能量'.md",
#         "20170712_在三季度区域总裁会议上的讲话.md",
#         "20170623_与波兰代表处交流纪要.md",
#         "20170111_在2017年市场工作大会上的讲话.md",
#         "20171018_在会议标准化及服务提升项目汇报会上的讲话.md",
#         "20171215_确定性工作精细化、自动化.md",
#         "20170527_在健康指导与应急保障业务整合及签证变革进展汇报会上的讲话.md",
#         "20170203_在厄瓜多尔代表处的讲话.md"
#       ],
#       "2015": [
#         "20150730_在战略预备队业务汇报上的讲话.md",
#         "20150713_在子公司监督型董事会管理层监督方案及试点情况汇报上的讲话.md",
#         "20150713_在合同场景师建设思路汇报上的讲话.md",
#         "20151031_聚焦主航道，在战略机会点上抢占机会.md",
#         "201509致新员工书.md",
#         "20150520_在公司质量工作汇报会上的讲话.md",
#         "20150318_在2015年全球行政工作年会上的讲话.md",
#         "20150731_在变革战略预备队第三期誓师典礼上的讲话.md",
#         "20150827_脚踏实地，做挑战自我的长跑者.md",
#         "20150331_在变革战略预备队进展汇报上的讲话.md",
#         "20150907_在战略预备队誓师典礼暨优秀队员表彰大会上的讲话.md",
#         "20150902_在波士顿咨询汇报行政服务变革（国家驻点成果及未来变革方向）的讲话.md",
#         "20150924_在2015年9月24日EMT办公会议上的讲话.md",
#         "20150116_变革的目的就是要多产粮食和增加土地肥力.md",
#         "20150408_埃森哲董事长Pierre拜访任正非的会谈纪要.md",
#         "20150702_在固网产业趋势及进展汇报会上的讲话.md",
#         "20150504_在变革战略预备队及进展汇报座谈上的讲话.md",
#         "20151218_彭剑锋专访任正非纪要.md",
#         "20150906_任正非接受福布斯中文网采访.md",
#         "20151023_将军是打出来的.md",
#         "20150515_在监管重装旅座谈会上的讲话.md",
#         "20151027_小国要率先实现精兵战略，让听得见炮声的人呼唤炮火.md",
#         "20150928_在GTS站点信息库、地理信息库、网络动态运行信息库和集成交付平台建设汇报会上的讲话.md",
#         "20150108_在与法务部、董秘及无线员工座谈会上的讲话.md",
#         "20151010_最终的竞争是质量的竞争.md",
#         "20150812_构建先进装备，沉淀核心能力，在更高维度打赢下一场战争.md",
#         "20151023_在调查工作授权及流程优化汇报上的讲话.md",
#         "20150109_打造运营商BG“三朵云”，将一线武装到牙齿.md",
#         "20150125_最大的敌人是我们自己.md",
#         "20150508_在变革战略预备队誓师及颁奖典礼上的座谈纪要.md",
#         "20150923_在公共及政府事务部2015年工作汇报会的讲话.md",
#         "20150828_在2015年8月28日EMT办公会议上的讲话.md",
#         "20150310_非主航道组织要率先实现流程责任制，通过流程责任来选拔管理者，淘汰不作为员工，为公司管理进步摸索经验.md",
#         "20150127_改善艰苦地区条件，加快循环赋能，为公司筑起第二道防线.md",
#         "20150714_与英国研究所、北京研究所、伦敦财经风险管控中心座谈的纪要.md",
#         "20150506_与BCG顾问交流会谈纪要.md"
#       ],
#       "2008": [
#         "20080705_任正非在PSST体系干部大会上的讲话.md",
#         "20080902_从泥坑里爬起来的人就是圣人.md",
#         "200807_理解国家，做好自己.md",
#         "20080922_从汶川特大地震一片瓦砾中，一座百年前建的教堂不倒所想到的.md",
#         "20080131_在EMT例会“08年公司业务计划与预算”汇报上的讲话.md",
#         "20081229_围绕客户PO打通，支撑“回款、收入、项目预核算”.md",
#         "20080410_人生是美好的，但过程确实是痛苦的.md",
#         "20080613_让青春的生命放射光芒.md",
#         "20080616_大家都是共和国的英雄.md",
#         "20080715_逐步加深理解“以客户为中心，以奋斗者为本”的企业文化.md",
#         "20080531_让青春的火花，点燃无愧无悔的人生.md",
#         "20070728_珍惜生命，要从自己关爱自己做起.md",
#         "2008_2008年新年祝词.md",
#         "20080215_看莫斯科保卫战有感.md",
#         "20080721_在地区部向EMT进行2008年年中述职会议上的讲话.md"
#       ],
#       "2001": [
#         "20010424_北国之春.md",
#         "20010208_我的父亲母亲.md",
#         "20010118_雄赳赳气昂昂跨过太平洋.md",
#         "20010201_华为的冬天.md"
#       ],
#       "1996": [
#         "19960406_反骄破满，在思想上艰苦奋斗.md",
#         "19960608_要树立服务意识、品牌意识、群体意识.md",
#         "19961213_坚持顾客导向同步世界潮流.md",
#         "19960725_我们是要向前迈进一小步，而不是一次大飞跃.md",
#         "19960128_当干部是一种责任.md",
#         "19960402_我们要向市场、开发、创造性工作倾斜.md",
#         "19961121_培训——通向华为明天的重要阶梯.md",
#         "19960630_再论反骄破满，在思想上艰苦奋斗.md",
#         "1996_不要叶公好龙.md",
#         "19961113_做好基础工作，逐步实现全面质量管理.md",
#         "19961202_管理改革，任重道远.md",
#         "19961228_团结起来接受挑战，克服自我溶入大我.md",
#         "19960828_秘书体系是信息桥.md",
#         "19961115_实行低重心管理，层层级级都要在做实上下功夫.md",
#         "19960502_加强合作走向世界.md",
#         "19960811_胜负无定数，敢搏成七分.md",
#         "19960828_赴俄参展杂记.md"
#       ],
#       "2007": [
#         "20070803_关于员工培训工作的谈话.md",
#         "20070824_内控体系建设就是要穿美国鞋，不打补丁.md",
#         "20070808_变革最重要的问题是一定要落地.md",
#         "20070108_财经的变革是华为公司的变革，不是财务系统的变革.md",
#         "20070612_以生动活泼的方式传递奋斗者为主体的文化.md",
#         "20070713_敢于胜利，才能善于胜利.md",
#         "20070315_在行政采购及信息安全问题座谈会上的讲话.md",
#         "20070914_将军如果不知道自己错在哪里，就永远不会成为将军.md",
#         "200702_要快乐的度过充满困难的一生.md",
#         "20070721_完善和提高对艰苦地区员工的保障措施.md",
#         "20070108_对区域监控工作的讲话纪要.md",
#         "20070409_听取艰苦地区生活专项问题汇报会上的讲话.md",
#         "20070703_上甘岭在你心中，无论何时何地都可以产生英雄.md"
#       ],
#       "2012": [
#         "20120712_中国没有创新土壤不开放就是死亡.md",
#         "20120412_紧紧围绕客户，在战略层面宣传公司.md",
#         "20121115_东南非多国管理部向任总汇报工作纪要.md",
#         "20121219_与华为大学教育学院座谈会纪要.md",
#         "20120423_董事会领导下的CEO轮值制度辨.md",
#         "201209_面向未来，以客户痛点为切入点，全球化展示.md",
#         "20120119_不要盲目扩张，不要自以为已经强大.md",
#         "20120319_绝对考核的目的是团结多数人.md",
#         "20121120_与毛里求斯员工座谈会议纪要.md"
#       ],
#       "2014": [
#         "20140105_风物长宜放眼量.md",
#         "20140331_在日本研究所工作汇报会上的讲话.md",
#         "20141218在艰苦地区及岗位管理部工作汇报会上的讲话.md",
#         "20140413_在拉美北地区部、哥伦比亚代表处工作汇报会上的讲话.md",
#         "20140416_在华为上研所专家座谈会上的讲话.md",
#         "20140527_在海外子公司董事会推行工作汇报会上的讲话.md",
#         "20141205_在“从中心仓到站点打通”工作汇报会上的讲话.md",
#         "20140307_在关于重装旅组织汇报会议上的讲话.md",
#         "20140311_在大机会时代，千万不要机会主义.md",
#         "20140225_在外派伙食补助汇报会上的讲话.md",
#         "20140616_为什么我们今天还要向“蓝血十杰”学习.md",
#         "20140513_推动行政服务业务变革，试点流程责任制.md",
#         "20140723_在变革项目激励政策汇报会上的讲话.md",
#         "20140606_在保加利亚代表处工作汇报会上的讲话.md",
#         "20140411_在秘鲁代表处座谈会上的讲话.md",
#         "20141106_遍地英雄下夕烟，六亿神州尽舜尧.md",
#         "20140122_在董事赋能研讨会上与候选专职董事交流讲话.md",
#         "20140707_第一次就把事情做对.md",
#         "20141218_依托欧美先进软件包构建高质量的IT系统.md",
#         "20141104_在行政流程责任制试点进展汇报会上的讲话.md",
#         "20140409_与巴西代表处及巴供中心座谈纪要.md",
#         "20141104_与CEC就非物质激励工作优化的座谈纪要.md",
#         "20141114_坚持为世界创造价值，为价值而创新.md",
#         "20140619_洞庭湖装不下太平洋的水.md",
#         "20140624_在“关于内部网络安全工作方向“的决议.md",
#         "20140509_喜马拉雅山的水为什么不能流入亚马逊河.md",
#         "20140509_简化管理，选拔使用有全局观的干部，数据及信息透明.md",
#         "20140327_在华大建设思路汇报会上的讲话.md",
#         "20140219_自我批判，不断超越.md",
#         "20140113_做谦虚的领导者.md",
#         "20140624_在人力资源工作汇报会上的讲话.md",
#         "20140604_在西欧地区部工作汇报会上的讲话.md",
#         "20140502_英国媒体会谈纪要.md",
#         "20140725_在2014年7月25日EMT办公会议上的讲话.md",
#         "20140826_在销售项目经理资源池第一期学员座谈会上的讲话.md",
#         "20140129_握紧拳头才有力量.md",
#         "20140314三年，从士兵到将军.md",
#         "20140424_在后备干部项目管理与经营短训项目座谈会上的讲话.md",
#         "20140510_在巡视松山湖制造现场的讲话纪要.md",
#         "20140723_在项目管理资源池第一期学员座谈会上的讲话.md",
#         "20140923_在公司近期激励导向和激励原则汇报会上的讲话.md",
#         "20140603_在丹麦代表处员工座谈会上的讲话.md",
#         "201409_在多个汇困国家调研中的讲话.md",
#         "20140605_在德国LTC教导队训战班座谈会上的讲话.md",
#         "20140723_在小国综合管理变革汇报会上的讲话.md",
#         "20140410_在巴西代表处的讲话.md",
#         "20140923_在“班长的战争”对华为的启示和挑战汇报会上的讲话.md"
#       ],
#       "2018": [
#         "20180314_任正非在2018年全球行政年会上的座谈纪要.md",
#         "20181119_加强与国内大学合作，吸纳全球优秀人才，共同推动中国基础研究.md",
#         "20180205_与“落实日落法及清理机关说NO”秘书处座谈会上的讲话.md",
#         "20180622_BG机关要缩短经线，畅通纬线，强化作战组织的能力考核与选拔，精减非作战组织的规模及运作.md",
#         "20180223_在斯里兰卡代表处的讲话.md",
#         "20180224_从系统工程角度出发规划华为大生产体系架构，建设世界一流的先进生产系统.md",
#         "20180209_在员工关系变革工作进展汇报上的讲话.md",
#         "20180627_与平台协调委员会座谈纪要.md",
#         "20180116_在财务部分员工座谈会上的讲话.md",
#         "20181017_坚持多路径、多梯次、多场景化的研发路线，攻上“上甘岭”，实现5G战略领先.md",
#         "20180701在卢旺达饭店与员工聊天记录.md",
#         "20180302_在蒙古办事处汇报会议上的讲话.md",
#         "20180605_在剑桥和伊普斯维奇研究所座谈纪要.md",
#         "20181019_鼓足干劲，力争上游，不畏一切艰苦困苦.md",
#         "20180713_在攀登珠峰的路上沿途下蛋.md",
#         "20180420_关于人力资源组织运作优化的讲话.md",
#         "20180623_在2018年IRB战略务虚研讨会的讲话.md",
#         "20181121_任正非在日本研究所业务汇报.md",
#         "20181107_寂寞的英雄是伟大的英雄，我们要鼓励新旧循环.md",
#         "20180117_从泥坑中爬起来的是圣人.md",
#         "20180321_研发要做智能世界的“发动机”.md",
#         "20180411_在黎巴嫩代表处的讲话.md",
#         "20180515_励精图治，十年振兴.md",
#         "20180929_从人类文明的结晶中，找到解决世界问题的钥匙.md",
#         "20180718在GTS人工智能实践进展汇报会上的讲话.md",
#         "20180118_与财务、基建、行政座谈会上的讲话.md",
#         "20180426_任正非在战略预备队述职会上的讲话.md"
#       ],
#       "2004": [
#         "20040428_华为公司的核心价值观.md",
#         "20040115_持续提高人均效益建设高绩效企业文化.md"
#       ],
#       "2005": [
#         "20050726_华为与对手做朋友海外不打价格战.md"
#       ],
#       "2016": [
#         "20161025_建立对作业类员工的科学管理方法与评价体系，导向多产粮食.md",
#         "20160113_决胜取决于坚如磐石的信念，信念来自专注.md",
#         "20160331_在巴展总结会议上的讲话.md",
#         "20160227_多路径多梯次跨越“上甘岭”攻进无人区.md",
#         "20160118_变革的目的就是更简单、更及时、更准确.md",
#         "201610_在中亚（塔吉克斯坦、土耳其、白俄）代表处汇报会议上的讲话.md",
#         "20160307_关于改善艰苦国家的作战环境.md",
#         "20161217_在法国研究所座谈交流纪要.md",
#         "20160712_前进的路上不会铺满了鲜花.md",
#         "20161222_在存货账实相符项目汇报会上的讲话.md",
#         "20161121_与合同场景师座谈会上的讲话.md",
#         "20160815_公司必须持续不断的、永恒的促进组织血液流动，增强优秀干部、专家的循环赋能.md",
#         "20160505_任正非与Fellow座谈会上的讲话.md",
#         "20161026_在运营商三朵云2.0阶段进展汇报会上的讲话.md",
#         "20160530_以创新为核心竞争力，为祖国百年科技振兴而奋斗.md",
#         "20160819_美丽的爱尔兰是软件的大摇篮.md",
#         "20161201_内外合规多打粮，保驾护航赢未来.md",
#         "20160528_为祖国百年科技振兴而努力奋斗.md",
#         "20160813_IPD的本质是从机会到商业变现.md",
#         "20160223_巴塞罗那通信展小型恳谈会纪要.md",
#         "20160805_聚焦战略平台，加强血液流动，夺取未来胜利.md",
#         "20160305_28年只对准一个城墙口冲锋.md",
#         "20161028_春江水暖鸭先知，不破楼兰誓不还.md",
#         "20160804_在签证业务变革进展汇报上的讲话.md",
#         "20161031_聚焦主航道，眼望星空，朋友越多天下越大.md",
#         "20160125_在2016年1月25日EMT办公会议上的讲话.md",
#         "20160428_在专业服务业务策略汇报上的讲话.md",
#         "20160405_与日本代表处、日本研究所员工座谈纪要.md",
#         "20161130_人力资源政策要朝着熵减的方向发展.md",
#         "20161115_聚焦平台，加强血液流动，敢于破格，抢占世界高地.md",
#         "20160523_在中亚地区部员工座谈会上的讲话.md",
#         "20161217_在法国美学研究所的讲话.md",
#         "20160214_做“成吉思汗的马掌”，支撑我们服务世界的雄心.md",
#         "20161026_在质量与流程IT管理部员工座谈会上的讲话.md",
#         "20161021_关于行政与慧通工作讲话的纪要.md",
#         "20160810_在诺亚方舟实验室座谈会上的讲话.md"
#       ],
#       "2011": [
#         "20111225_一江春水向东流.md",
#         "20110414_华为关于如何与奋斗者分享利益的座谈会纪要.md",
#         "20110117_成功不是未来前进的可靠向导.md",
#         "20110614_任总与罗马尼亚账务共享中心座谈会纪要.md",
#         "20110727_与华为大学第10期干部高级管理研讨班学员座谈纪要.md",
#         "20111019_任正非与财经体系员工座谈讲话.md",
#         "20111031_力出一孔，要集中优势资源投入在主航道上，敢于去争取更大的机会与差距.md",
#         "20110223_关于珍爱生命与职业责任的讲话.md",
#         "20111026_与同等学历认证班学员座谈纪要.md"
#       ],
#       "2009": [
#         "20091127_加快CFO队伍建设，支撑IFS推行落地.md",
#         "20090116_谁来呼唤炮火，如何及时提供炮火支援.md",
#         "20091026_CFO要走向流程化和职业化，支撑公司及时、准确、优质、低成本交付.md",
#         "20090827_具有“长期持续艰苦奋斗的牺牲精神，永恒不变的艰苦奋斗的工作作风”是成为一个将军最基本条件.md",
#         "20090324_市场经济是最好的竞争方式，经济全球化是不可阻挡的潮流.md",
#         "20090116_让听得见炮声的人来决策.md",
#         "20090327_任正非与PMS高端项目经理的座谈纪要.md",
#         "20090206_任正非与IFS项目组及财经体系员工座谈纪要.md",
#         "20090424_深淘滩，低作堰.md",
#         "20090312_在驻外行政人员培训交流沟通会上的座谈纪要.md",
#         "20090115_开放、妥协与灰度.md"
#       ],
#       "2003": [
#         "2003_在自我批判指导委员会座谈会上的讲话.md",
#         "2003_发挥核心团队作用，不断提高人均效益.md",
#         "20030526_产品发展的路标是客户需求导向企业管理的目标是流程化的组织建设.md",
#         "20030525_在理性与平实中存活.md"
#       ],
#       "1999": [
#         "19990520_“中国人今天说不”图片新闻感想.md",
#         "19990520_能工巧匠是我们企业的宝贵财富.md",
#         "199904_在实践中培养和选拔干部.md",
#         "19990720_任正非答新员工问.md",
#         "19990208_创业创新必须以提升企业核心竞争力为中心.md",
#         "19990417_在IPD动员大会上的讲话.md"
#       ],
#       "2013": [
#         "20131106_在华为大学教育学院工作汇报会上的讲话.md",
#         "2013_CFO标准与培养机制向任总汇报纪要.md",
#         "20130719_要培养一支能打仗、打胜仗的队伍.md",
#         "20130517_要敢于超越美国公司，最多就是输.md",
#         "20131230_任正非在大规模消灭腐败进展汇报会上的讲话.md",
#         "20131019_用乌龟精神，追上龙飞船.md",
#         "20131222_聚焦商业成功，英雄不问出处.md",
#         "20131204_在公司内控与风险管理“三层防线”优化方案汇报的讲话.md",
#         "20131111_在IP交付保障团队座谈会上的讲话.md",
#         "20130330_家人永远不接班.md",
#         "20131129_在EMT办公例会上的讲话.md",
#         "20130911_提倡节俭办晚会，节约会议成本.md",
#         "20130904_在GTS客户培训服务座谈会上的讲话.md",
#         "20130911_团结一切可以团结的力量.md",
#         "20131031_与CEC成员座谈会的讲话.md",
#         "20121231_力出一孔，利出一孔.md",
#         "20130114_在小国表彰会上的讲话.md",
#         "20130723_在重装旅集训营座谈会上的讲话.md",
#         "20130905_最好的防御就是进攻.md",
#         "20130627_财经流程建设向任总汇报纪要.md",
#         "20130219_任总和广州代表处座谈纪要.md",
#         "20131219_关于“严格、有序、简化的认真管理是实现超越的关键”的座谈纪要.md",
#         "20131105_在GTS网规网优业务座谈会上的讲话.md",
#         "20130527_在海外行政后勤服务管理思路汇报会上的讲话.md",
#         "20131125_我一贯不是一个低调的人.md",
#         "20131228在运营商网络BG战略务虚会上的讲话及主要讨论发言.md",
#         "20130929_财经向任正非汇报纪要.md"
#       ],
#       "2006": [
#         "20061218_实事求是的科研方向与二十年的艰苦努力.md",
#         "20060510_在华为收购港湾时的谈话纪要.md",
#         "20060904_上甘岭是不会自然产生将军的但将军都曾经是英雄.md",
#         "20060721_天道酬勤.md",
#         "20061120_华为大学要成为将军的摇篮.md",
#         "20060430_全流程降低成本和费用提高盈利能力.md",
#         "20061214_在BT系统部、英国代表处汇报会上的讲话.md",
#         "20060719_我的青春岁月.md",
#         "200608_冰岛游记.md"
#       ],
#       "1998": [
#         "19980328_要从必然王国，走向自由王国.md",
#         "19981209_印度随笔.md",
#         "1998_把生命注入到产品中去.md",
#         "19980116_狭路相逢勇者生.md",
#         "199803_华为基本法.md",
#         "1998012_不做昙花一现的英雄.md",
#         "19980716_小改进、大奖励.md",
#         "199809_全心全意对产品负责全心全意为客户服务.md",
#         "199803_在自我批判中进步.md",
#         "19980620_华为的红旗到底能打多久.md",
#         "199805_希望寄托在你们身上.md",
#         "19980220_我们向美国人民学习什么.md"
#       ],
#       "2000": [
#         "20000717_沟通从心灵开始.md",
#         "20000408_活下去，是企业的硬道理.md",
#         "20000720_创新是华为发展的不竭动力.md",
#         "20000114_与身处逆境员工的对话录.md",
#         "20000320_一个职业管理者的责任和使命.md",
#         "2000_任正非在秘书资格颁证大会上的讲话.md",
#         "20000128_凤凰展翅再创辉煌.md",
#         "20000901_为什么要自我批判.md"
#       ],
#       "1994": [
#         "19940118_赴美考察散记.md",
#         "19940605_胜利祝酒辞.md",
#         "19941225_从二则空难事故看员工培训的重要性.md",
#         "19941225_致新员工书.md",
#         "19940621_对中国农话网与交换机产业的一点看法.md",
#         "19940126_团结奋斗_再创华为佳绩.md"
#       ],
#       "2002": [
#         "2002_迎接挑战，苦练内功，迎接春天的到来.md"
#       ],
#       "1997": [
#         "1997_我们需要什么样的干部.md",
#         "19970428_走过亚欧分界线.md",
#         "19970330_悼念杨琳.md",
#         "19970626_呼唤英雄.md",
#         "19970916_当代青年怎样爱国.md",
#         "1997_建立一个适应企业生存发展的组织和机制.md",
#         "19970217_加强用户服务中心建设，不断提高用户服务水平.md",
#         "19970410_自强不息，荣辱与共，促进管理的进步.md",
#         "19970912_提升自我，找到切入点，迎接人生新挑战.md",
#         "19970226_胜则举杯相庆败则拼死相救.md",
#         "19970226_坚定不移地推行ISO9000.md",
#         "199705_加强夏收管理促进增产增收.md",
#         "19970123_不要忘记英雄.md",
#         "1997_在《委员会管理法》评审上的重要讲话.md",
#         "1997_苦练基本功，争做维护专家.md",
#         "19970207_资源是会枯竭的，唯有文化才能生生不息.md",
#         "19970428_谈学习.md",
#         "19970222_秘书如何定位.md",
#         "19970715_为提高电信网营运水平而努力.md"
#       ],
#       "2010": [
#         "2000_以客户为中心，加大平台投入，开放合作，实现共赢.md",
#         "20110104_以“选拔制”建设干部队伍，按流程梳理和精简组织，推进组织公开性和均衡性建设.md",
#         "20100715_干部要担负起公司价值观的传承.md",
#         "20091231_春风送暖入屠苏.md",
#         "20100304_在全球行政人员年度表彰暨经验交流大会座谈纪要.md",
#         "20100910_开放、合作、自我批判，做容千万家的天下英雄.md",
#         "20100120_以客户为中心，以奋斗者为本，长期坚持艰苦奋斗是我们胜利之本.md",
#         "20101206_五彩云霞飞遍天涯.md",
#         "20101031_世博结束了，我们胜利了.md",
#         "20101125z_改善和媒体的关系.md",
#         "20100430_拉通项目四算，支撑项目层面经营管理.md",
#         "20101203_做事要霸气，做人要谦卑，要按消费品的规律，敢于追求最大的增长和胜利.md"
#       ]
#     }
#   },
#   "file": {
#     "list": [
#       "R&D.md",
#       "README.md",
#       "SUMMARY.md"
#     ]
#   },
#   "word_list": [],
#   "word_dict": {}
# }

# %%
s='19950110_不前进就免职.md'
res = pattern_title.match(s)
if res:
    print(res.groups()[0])
# Out:
# 不前进就免职

# %%
import jieba
from jieba import analyse
import re

# 标题提取正则, 19990520_能工巧匠是我们企业的宝贵财富.md
pattern_title = re.compile('.*_(.*?)\.md')
presentation_dict = {'num':{}, 'kw_title':{},'kw_article':{},
                     'kw_part':{'1994-2005':{}, '2006-2012':{}, '2013-2018':{}}
                    }
# 词库补充
w_set = ('诺亚方舟', '华为大学', '自我批判', '能工巧匠', '中国农话网', '世博', '火车头')
#jieba.load('a.txt')# w f pos
for w in w_set:
    jieba.add_word(w)
for k,v in data_dict['dir']['title'].items():
    # 遍历每年的讲话文本
    print(k, v)
    # (1)读取文件标题
    v1 = []
    for article in v:
        # 提取标题内容
        #res = pattern_title.search(article)
        res = pattern_title.match(article)
        if res:
            #v1.append(res[0])
            title = res.groups()[0]
            v1.append(title)
            # 提取关键词
            res = analyse.extract_tags(title)
            for r in res:
                presentation_dict['kw_title'][r] = presentation_dict['kw_title'].get(r, 0) + 1
            #presentation_dict['kw'].append(res)
        # (2)读取列表文件内容
        file_name = 'RenZhengfei/{}/{}'.format(k,article)
        idx = 0
        for line in open(file_name):
            if not line.strip():
                continue
            idx += 1
            #print(idx,line)
            # 提取关键词
            res = analyse.extract_tags(title)
            for r in res:
                # 全部词频
                presentation_dict['kw_article'][r] = presentation_dict['kw_article'].get(r, 0) + 1
                # 分阶段词频
                part_k = '-'
                if int(k) <= 2005: # 1994-2005,2006-2012,2013-2018
# %%
import pandas as pd

# key_list = sorted(presentation_dict['num'].keys())
# val_list = [ presentation_dict['num'][i] for i in key_list]
#df = pd.DataFrame.from_dict(presentation_dict['num'], orient='index')
df = pd.DataFrame(list(presentation_dict['num'].items()), columns=['year','number'])
# pd.DataFrame(list(my_dict.items()), columns=['A', 'B'])
# df.hist()
df.sort_values(by=['year'], ascending=False)[:10]
#df.filter(lambda x: x.year in ['1995'])
#df[(True^df['year'].isin(['1995','1999']))] # 过滤特定值
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00a05c29c33b> in <module>()
#       4 # val_list = [ presentation_dict['num'][i] for i in key_list]
#       5 #df = pd.DataFrame.from_dict(presentation_dict['num'], orient='index')
# ----> 6 df = pd.DataFrame(list(presentation_dict['num'].items()), columns=['year','number'])
#       7 # pd.DataFrame(list(my_dict.items()), columns=['A', 'B'])
#       8 # df.hist()
#
# NameError: name 'presentation_dict' is not defined

# %%
# 需要实际含义的关键词表
null_list = ['讲话','纪要','座谈', '座谈会','会议', '大会', '汇报', '汇报会', '交流','我们', '一个', '关于', '代表会', '代表处', '就是',
            '目前', '到底', '不断', '多少', '会上', '没有', '知道', '哪里', '不是', '进展', '可以', '不要',
            '提高', '学员', '找到', '分享', '构建', '建设', '增长', '追求', '沟通', '今天', '坚持', '多久',
            '实现', '加强', '最大', '路上', '如何', '还要', '成为', '产生', '方向', '坚苦',
            '任正非', '工作', '企业', '10', 'IFS', 'BG']
#df[(True^df['keyword'].isin(null_list))]
# 标题关键词
df_w_t = pd.DataFrame(list(presentation_dict['kw_title'].items()), columns=['keyword', 'count'])
df_w_t = df_w_t[(True^df_w_t['keyword'].isin(null_list))] # 过滤信息量不大的词语
df_w_t_sort = df_w_t.sort_values(by='count', ascending=False)
# 内容关键词-整体
df_w_a = pd.DataFrame(list(presentation_dict['kw_article'].items()), columns=['keyword', 'count'])
df_w_a = df_w_a[(True^df_w_a['keyword'].isin(null_list))] # 过滤信息量不大的词语
df_w_a_sort = df_w_a.sort_values(by='count', ascending=False)
# 内容关键词-分阶段
part_dict = {}
for part in presentation_dict['kw_part']:
    part_dict[part] = {}
    df_w_p = pd.DataFrame(list(presentation_dict['kw_part'][part].items()), columns=['keyword', 'count'])
    df_w_p = df_w_p[(True^df_w_p['keyword'].isin(null_list))] # 过滤信息量不大的词语
    part_dict[part] = df_w_p.sort_values(by='count', ascending=False)
# 显示top样例
top_n = 10
# df_w_t_sort[:top_n]
# df_w_a_sort[:top_n]
# part_dict[part]
#df_w_t_sort['count'][:top_n]
df_w_a_sort[120:]
# Out:
#      keyword  count
# 1061      霸气     87
# 1062      谦卑     87
# 1063      做人     87
# 1064      做事     87
# 535       向任     86
# 35       研讨会     86
# 22        通信     86
# 193      董事会     86
# 249       试点     85
# 276       国家     85
# 111       人力     85
# 739       攻进     85
# 813       成功     85
# 741       跨越     85
# 110       纲要     85
# 108     资源管理     85
# 740      无人区     85
# 885       机制     84
# 3         任务     83
# 2         形势     83
# 403       生命     82
# 630     项目经理     81
# 346      责任制     81
# 493     华为公司     80
# 778       商业     80
# 266       自我     80
# 752       鲜花     79
# 751       铺满     79
# 142      竞争力     79
# 567       推行     78
# ...      ...    ...
# 706       新旧      7
# 707       寂寞      7
# 709       鼓励      7
# 708       伟大      7
# 135       四位      7
# 136       弟兄      7
# 98      玻利维亚      7
# 748      土耳其      7
# 747       中亚      7
# 746    塔吉克斯坦      7
# 745       白俄      7
# 744       简单      7
# 802       美学      6
# 247     厄瓜多尔      6
# 242      自动化      6
# 241      精细化      6
# 979      祝酒辞      6
# 675     斯里兰卡      6
# 980       空难      6
# 981       二则      6
# 176      巴拉圭      6
# 982      重要性      6
# 983       事故      6
# 97        捷克      5
# 712      黎巴嫩      5
# 585     保加利亚      5
# 876       新闻      5
# 875       图片      5
# 874       感想      5
# 690       蒙古      5
#
# [897 rows x 2 columns]

# %%
key_list = ['任正非', '胸怀', '创新', '格局', '领导力']
[df_w_a['keyword'].get(i, 0) for i in key_list]
df_w_a[df_w_a['keyword'].isin(key_list)]
# Out:
#     keyword  count
# 161     任正非    698
# 185      创新    209

# %%
#每次在colab刷新笔记时，需要重新执行安装程序
#!pip install pyecharts==0.5.1

# %%
#presentation_dict['num']

# %%
#先安装pip install pyecharts==0.5.1
from IPython.display import HTML, SVG
# from IPython.core.magic import register_cell_magic

import pyecharts as pe

page = pe.Page('任正非历年讲话挖掘')
# (1) 历年讲话次数
key_list = sorted(presentation_dict['num'].keys())
val_list = [presentation_dict['num'][i] for i in key_list]
overlap = pe.Overlap()
t1 = '任正非历年公开讲话次数变化'
s1 = '时间跨度: 1994-2018, 过滤部分无实际意义的高频词汇'
bar = pe.Bar(t1, subtitle=s1, title_pos='center')
bar.add('bar', key_list, val_list, legend_pos='right')
#bar.use_theme('dark')
es = pe.EffectScatter(t1)
es.add("es",key_list, val_list, effect_scale=2)
line = pe.Line(t1, title_pos='center')
line.add('line', key_list, val_list, legend_pos='right', mark_point=['min','max'], is_more_utils=True,is_label_show=True)
overlap.add(line)
overlap.add(bar)
overlap.add(es)
page.add(overlap)
# (2) 标题关键词词云
#person_count = {}
kw_list = df_w_t_sort['keyword']
freq_list = df_w_t_sort['count']
#-饼图
top_n = 30
pie = pe.Pie('历年讲话主题词-源自标题', subtitle=s1, title_pos='center')
pie.add("", kw_list[:top_n], freq_list[:top_n], legend_pos='bottom', is_label_show=True,is_more_utils=True)
page.add(pie)
#-词云
chart = pe.WordCloud('历年讲话主题词-源自标题', subtitle=s1, title_pos='center')
#chart.add("", kw_list, freq_list, word_size_range=[10, 500], rotate_step=66) # 这种设置会丢失高频词
chart.add("", kw_list, freq_list,is_more_utils=True)
page.add(chart)
# 统计台词数
#person_count[person] = person_count.get(person, 0) + len(sen_dict[scene][person])

# wordcloud参数说明: https://www.jianshu.com/p/23200304409c
# (3) 内容关键词词云-总体
kw_list = df_w_a_sort['keyword']
freq_list = df_w_a_sort['count']
#-饼图
pie = pe.Pie('历年讲话主题词-源自内容', subtitle=s1, title_pos='center')
pie.add("", kw_list[:top_n], freq_list[:top_n], legend_pos='bottom', is_label_show=True,is_more_utils=True)
page.add(pie)
#-词云
chart = pe.WordCloud('历年讲话主题词-源自内容-整体', subtitle=s1, title_pos='center')
chart.add("", kw_list, freq_list)
#chart.add("", kw_list, freq_list, word_size_range=[10, 1000], rotate_step=66)
page.add(chart)
top_n = 40
# (4) 内容关键词词云-分阶段, 1994-2005, 2006-2012, 2013-2018
for part in part_dict:
    kw_list = part_dict[part]['keyword'][:top_n]
    freq_list = part_dict[part]['count'][:top_n]
    #-饼图
    pie = pe.Pie('饼图-历年讲话主题词-源自内容-局部', subtitle='{},Top {}'.format(part,top_n), title_pos='center')
    pie.add("", kw_list[:top_n], freq_list[:top_n], legend_pos='bottom', is_more_utils=True,is_label_show=True)
    page.add(pie)
    #-词云
    chart = pe.WordCloud('词云-历年讲话主题词-源自内容-局部', subtitle='{},Top {}'.format(part,top_n), title_pos='center')
    #chart.add("", kw_list, freq_list, word_size_range=[10, 800], rotate_step=66)
    chart.add("", kw_list, freq_list, shape='circle')
    page.add(chart)

# 统一绘制、落地
out_file = 'page_huawei.html'
page.render(out_file)
HTML(out_file)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>任正非历年讲话挖掘</title>
#     <script type="text/javascript">
# !function(t,e){"object"==typeof exports&&"undefined"!=typeof module?e(exports):"function"==typeof define&&define.amd?define(["exports"],e):e(t.echarts={})}(this,function(t){"use strict";function e(t,e){"createCanvas"===t&&(Gx=null),Bx[t]=e}function i(t){if(null==t||"object"!=typeof t)return t;var e=t,n=kx.call(t);if("[object Array]"===n){if(!O(t)){e=[];for(var o=0,a=t.length;o<a;o++)e[o]=i(t[o])}}else if(Lx[n]){if(!O(t)){var r=t.constructor;if(t.constructor.from)e=r.from(t);else{e=new r(t.length);for(var o=0,a=t.length;o<a;o++)e[o]=i(t[o])}}}else if(!Cx[n]&&!O(t)&&!M(t)){e={};for(var s in t)t.hasOwnProperty(s)&&(e[s]=i(t[s]))}return e}function n(t,e,o){if(!w(e)||!w(t))return o?i(e):t;for(var a in e)if(e.hasOwnProperty(a)){var r=t[a],s=e[a];!w(s)||!w(r)||y(s)||y(r)||M(s)||M(r)||b(s)||b(r)||O(s)||O(r)?!o&&a in t||(t[a]=i(e[a],!0)):n(r,s,o)}return t}function o(t,e){for(var i=t[0],o=1,a=t.length;o<a;o++)i=n(i,t[o],e);return i}function a(t,e){for(var i in e)e.hasOwnProperty(i)&&(t[i]=e[i]);return t}function r(t,e,i){for(var n in e)e.hasOwnProperty(n)&&(i?null!=e[n]:null==t[n])&&(t[n]=e[n]);return t}function s(){return Gx||(Gx=Vx().getContext("2d")),Gx}function l(t,e){if(t){if(t.indexOf)return t.indexOf(e);for(var i=0,n=t.length;i<n;i++)if(t[i]===e)return i}return-1}function u(t,e){function i(){}var n=t.prototype;i.prototype=e.prototype,t.prototype=new i;for(var o in n)t.prototype[o]=n[o];t.prototype.constructor=t,t.superClass=e}function h(t,e,i){r(t="prototype"in t?t.prototype:t,e="prototype"in e?e.prototype:e,i)}function c(t){if(t)return"string"!=typeof t&&"number"==typeof t.length}function d(t,e,i){if(t&&e)if(t.forEach&&t.forEach===Nx)t.forEach(e,i);else if(t.length===+t.length)for(var n=0,o=t.length;n<o;n++)e.call(i,t[n],n,t);else for(var a in t)t.hasOwnProperty(a)&&e.call(i,t[a],a,t)}function f(t,e,i){if(t&&e){if(t.map&&t.map===zx)return t.map(e,i);for(var n=[],o=0,a=t.length;o<a;o++)n.push(e.call(i,t[o],o,t));return n}}function p(t,e,i,n){if(t&&e){if(t.reduce&&t.reduce===Rx)return t.reduce(e,i,n);for(var o=0,a=t.length;o<a;o++)i=e.call(n,i,t[o],o,t);return i}}function g(t,e,i){if(t&&e){if(t.filter&&t.filter===Ox)return t.filter(e,i);for(var n=[],o=0,a=t.length;o<a;o++)e.call(i,t[o],o,t)&&n.push(t[o]);return n}}function m(t,e){var i=Ex.call(arguments,2);return function(){return t.apply(e,i.concat(Ex.call(arguments)))}}function v(t){var e=Ex.call(arguments,1);return function(){return t.apply(this,e.concat(Ex.call(arguments)))}}function y(t){return"[object Array]"===kx.call(t)}function x(t){return"function"==typeof t}function _(t){return"[object String]"===kx.call(t)}function w(t){var e=typeof t;return"function"===e||!!t&&"object"==e}function b(t){return!!Cx[kx.call(t)]}function S(t){return!!Lx[kx.call(t)]}function M(t){return"object"==typeof t&&"number"==typeof t.nodeType&&"object"==typeof t.ownerDocument}function I(t){return t!==t}function D(t){for(var e=0,i=arguments.length;e<i;e++)if(null!=arguments[e])return arguments[e]}function T(t,e){return null!=t?t:e}function A(t,e,i){return null!=t?t:null!=e?e:i}function C(){return Function.call.apply(Ex,arguments)}function L(t){if("number"==typeof t)return[t,t,t,t];var e=t.length;return 2===e?[t[0],t[1],t[0],t[1]]:3===e?[t[0],t[1],t[2],t[1]]:t}function k(t,e){if(!t)throw new Error(e)}function P(t){return null==t?null:"function"==typeof t.trim?t.trim():t.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g,"")}function N(t){t[Fx]=!0}function O(t){return t[Fx]}function E(t){function e(t,e){i?n.set(t,e):n.set(e,t)}var i=y(t),n=this;t instanceof E?t.each(e):t&&d(t,e)}function z(t){return new E(t)}function R(t,e){for(var i=new t.constructor(t.length+e.length),n=0;n<t.length;n++)i[n]=t[n];var o=t.length;for(n=0;n<e.length;n++)i[n+o]=e[n];return i}function B(){}function V(t,e){var i=new Hx(2);return null==t&&(t=0),null==e&&(e=0),i[0]=t,i[1]=e,i}function G(t,e){return t[0]=e[0],t[1]=e[1],t}function F(t){var e=new Hx(2);return e[0]=t[0],e[1]=t[1],e}function W(t,e,i){return t[0]=e,t[1]=i,t}function H(t ...

# %%
import bs4

soup = bs4.BeautifulSoup(open(out_file))
soup.head.append('作者: wqw547243068@163.com, <a href="https://github.com/wqw547243068/Python-learning/blob/master/data_mining/huawei.ipynb">代码地址</a>')
soup.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>任正非历年讲话挖掘</title>
# <script type="text/javascript">
# !function(t,e){"object"==typeof exports&&"undefined"!=typeof module?e(exports):"function"==typeof define&&define.amd?define(["exports"],e):e(t.echarts={})}(this,function(t){"use strict";function e(t,e){"createCanvas"===t&&(Gx=null),Bx[t]=e}function i(t){if(null==t||"object"!=typeof t)return t;var e=t,n=kx.call(t);if("[object Array]"===n){if(!O(t)){e=[];for(var o=0,a=t.length;o<a;o++)e[o]=i(t[o])}}else if(Lx[n]){if(!O(t)){var r=t.constructor;if(t.constructor.from)e=r.from(t);else{e=new r(t.length);for(var o=0,a=t.length;o<a;o++)e[o]=i(t[o])}}}else if(!Cx[n]&&!O(t)&&!M(t)){e={};for(var s in t)t.hasOwnProperty(s)&&(e[s]=i(t[s]))}return e}function n(t,e,o){if(!w(e)||!w(t))return o?i(e):t;for(var a in e)if(e.hasOwnProperty(a)){var r=t[a],s=e[a];!w(s)||!w(r)||y(s)||y(r)||M(s)||M(r)||b(s)||b(r)||O(s)||O(r)?!o&&a in t||(t[a]=i(e[a],!0)):n(r,s,o)}return t}function o(t,e){for(var i=t[0],o=1,a=t.length;o<a;o++)i=n(i,t[o],e);return i}function a(t,e){for(var i in e)e.hasOwnProperty(i)&&(t[i]=e[i]);return t}function r(t,e,i){for(var n in e)e.hasOwnProperty(n)&&(i?null!=e[n]:null==t[n])&&(t[n]=e[n]);return t}function s(){return Gx||(Gx=Vx().getContext("2d")),Gx}function l(t,e){if(t){if(t.indexOf)return t.indexOf(e);for(var i=0,n=t.length;i<n;i++)if(t[i]===e)return i}return-1}function u(t,e){function i(){}var n=t.prototype;i.prototype=e.prototype,t.prototype=new i;for(var o in n)t.prototype[o]=n[o];t.prototype.constructor=t,t.superClass=e}function h(t,e,i){r(t="prototype"in t?t.prototype:t,e="prototype"in e?e.prototype:e,i)}function c(t){if(t)return"string"!=typeof t&&"number"==typeof t.length}function d(t,e,i){if(t&&e)if(t.forEach&&t.forEach===Nx)t.forEach(e,i);else if(t.length===+t.length)for(var n=0,o=t.length;n<o;n++)e.call(i,t[n],n,t);else for(var a in t)t.hasOwnProperty(a)&&e.call(i,t[a],a,t)}function f(t,e,i){if(t&&e){if(t.map&&t.map===zx)return t.map(e,i);for(var n=[],o=0,a=t.length;o<a;o++)n.push(e.call(i,t[o],o,t));return n}}function p(t,e,i,n){if(t&&e){if(t.reduce&&t.reduce===Rx)return t.reduce(e,i,n);for(var o=0,a=t.length;o<a;o++)i=e.call(n,i,t[o],o,t);return i}}function g(t,e,i){if(t&&e){if(t.filter&&t.filter===Ox)return t.filter(e,i);for(var n=[],o=0,a=t.length;o<a;o++)e.call(i,t[o],o,t)&&n.push(t[o]);return n}}function m(t,e){var i=Ex.call(arguments,2);return function(){return t.apply(e,i.concat(Ex.call(arguments)))}}function v(t){var e=Ex.call(arguments,1);return function(){return t.apply(this,e.concat(Ex.call(arguments)))}}function y(t){return"[object Array]"===kx.call(t)}function x(t){return"function"==typeof t}function _(t){return"[object String]"===kx.call(t)}function w(t){var e=typeof t;return"function"===e||!!t&&"object"==e}function b(t){return!!Cx[kx.call(t)]}function S(t){return!!Lx[kx.call(t)]}function M(t){return"object"==typeof t&&"number"==typeof t.nodeType&&"object"==typeof t.ownerDocument}function I(t){return t!==t}function D(t){for(var e=0,i=arguments.length;e<i;e++)if(null!=arguments[e])return arguments[e]}function T(t,e){return null!=t?t:e}function A(t,e,i){return null!=t?t:null!=e?e:i}function C(){return Function.call.apply(Ex,arguments)}function L(t){if("number"==typeof t)return[t,t,t,t];var e=t.length;return 2===e?[t[0],t[1],t[0],t[1]]:3===e?[t[0],t[1],t[2],t[1]]:t}function k(t,e){if(!t)throw new Error(e)}function P(t){return null==t?null:"function"==typeof t.trim?t.trim():t.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g,"")}function N(t){t[Fx]=!0}function O(t){return t[Fx]}function E(t){function e(t,e){i?n.set(t,e):n.set(e,t)}var i=y(t),n=this;t instanceof E?t.each(e):t&&d(t,e)}function z(t){return new E(t)}function R(t,e){for(var i=new t.constructor(t.length+e.length),n=0;n<t.length;n++)i[n]=t[n];var o=t.length;for(n=0;n<e.length;n++)i[n+o]=e[n];return i}function B(){}function V(t,e){var i=new Hx(2);return null==t&&(t=0),null==e&&(e=0),i[0]=t,i[1]=e,i}function G(t,e){return t[0]=e[0],t[1]=e[1],t}function F(t){var e=new Hx(2);return e[0]=t[0],e[1]=t[1],e}function W(t,e,i){return t[0]=e,t[1]=i,t}function H(t ...
#
# </script>
# <script type="text/javascript">
# !function(t,e){"object"==typeof exports&&"object"==typeof module?module.exports=e(require("echarts")):"function"==typeof define&&define.amd?define(["echarts"],e):"object"==typeof exports?exports["echarts-wordcloud"]=e(require("echarts")):t["echarts-wordcloud"]=e(t.echarts)}(this,function(t){return function(t){function e(n){if(r[n])return r[n].exports;var i=r[n]={i:n,l:!1,exports:{}};return t[n].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var r={};return e.m=t,e.c=r,e.d=function(t,r,n){e.o(t,r)||Object.defineProperty(t,r,{configurable:!1,enumerable:!0,get:n})},e.n=function(t){var r=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(r,"a",r),r},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=25)}([function(t,e){function r(t){if(null==t||"object"!=typeof t)return t;var e=t,n=W.call(t);if("[object Array]"===n){e=[];for(var i=0,a=t.length;i<a;i++)e[i]=r(t[i])}else if(E[n]){var o=t.constructor;if(t.constructor.from)e=o.from(t);else{e=new o(t.length);for(var i=0,a=t.length;i<a;i++)e[i]=r(t[i])}}else if(!N[n]&&!F(t)&&!T(t)){e={};for(var s in t)t.hasOwnProperty(s)&&(e[s]=r(t[s]))}return e}function n(t,e,i){if(!S(e)||!S(t))return i?r(e):t;for(var a in e)if(e.hasOwnProperty(a)){var o=t[a],s=e[a];!S(s)||!S(o)||w(s)||w(o)||T(s)||T(o)||M(s)||M(o)||F(s)||F(o)?!i&&a in t||(t[a]=r(e[a],!0)):n(o,s,i)}return t}function i(t,e){for(var r=t[0],i=1,a=t.length;i<a;i++)r=n(r,t[i],e);return r}function a(t,e){for(var r in e)e.hasOwnProperty(r)&&(t[r]=e[r]);return t}function o(t,e,r){for(var n in e)e.hasOwnProperty(n)&&(r?null!=e[n]:null==t[n])&&(t[n]=e[n]);return t}function s(){return document.createElement("canvas")}function l(){return z||(z=U.createCanvas().getContext("2d")),z}function h(t,e){if(t){if(t.indexOf)return t.indexOf(e);for(var r=0,n=t.length;r<n;r++)if(t[r]===e)return r}return-1}function u(t,e){function r(){}var n=t.prototype;r.prototype=e.prototype,t.prototype=new r;for(var i in n)t.prototype[i]=n[i];t.prototype.constructor=t,t.superClass=e}function c(t,e,r){t="prototype"in t?t.prototype:t,e="prototype"in e?e.prototype:e,o(t,e,r)}function f(t){if(t)return"string"!=typeof t&&"number"==typeof t.length}function d(t,e,r){if(t&&e)if(t.forEach&&t.forEach===H)t.forEach(e,r);else if(t.length===+t.length)for(var n=0,i=t.length;n<i;n++)e.call(r,t[n],n,t);else for(var a in t)t.hasOwnProperty(a)&&e.call(r,t[a],a,t)}function g(t,e,r){if(t&&e){if(t.map&&t.map===Y)return t.map(e,r);for(var n=[],i=0,a=t.length;i<a;i++)n.push(e.call(r,t[i],i,t));return n}}function p(t,e,r,n){if(t&&e){if(t.reduce&&t.reduce===V)return t.reduce(e,r,n);for(var i=0,a=t.length;i<a;i++)r=e.call(n,r,t[i],i,t);return r}}function v(t,e,r){if(t&&e){if(t.filter&&t.filter===j)return t.filter(e,r);for(var n=[],i=0,a=t.length;i<a;i++)e.call(r,t[i],i,t)&&n.push(t[i]);return n}}function m(t,e,r){if(t&&e)for(var n=0,i=t.length;n<i;n++)if(e.call(r,t[n],n,t))return t[n]}function x(t,e){var r=X.call(arguments,2);return function(){return t.apply(e,r.concat(X.call(arguments)))}}function y(t){var e=X.call(arguments,1);return function(){return t.apply(this,e.concat(X.call(arguments)))}}function w(t){return"[object Array]"===W.call(t)}function _(t){return"function"==typeof t}function b(t){return"[object String]"===W.call(t)}function S(t){var e=typeof t;return"function"===e||!!t&&"object"==e}function M(t){return!!N[W.call(t)]}function T(t){return"object"==typeof t&&"number"==typeof t.nodeType&&"object"==typeof t.ownerDocument}function k(t){return t!==t}function C(t){for(var e=0,r=arguments.length;e<r;e++)if(null!=arguments[e])return arguments[e]}function P(t,e){return null!=t?t:e}function I(t,e,r){return null!=t?t:null!=e?e:r}function A(){return Function.call.apply(X,arguments)}function O(t){if("number"==typeof t)return[t,t,t,t];var e=t.length;return 2===e?[t[0],t[1],t[0],t[1]]:3===e?[t[0],t[1],t[2],t[1]]:t}function D(t,e){if(!t)throw new Error(e)}function L(t){t[G]=!0}function F(t){return t[G]}function R(t){t&&d(t,function(t,e){this.set ...
#  * wordcloud2.js
#  * http://timdream.org/wordcloud2.js/
#  *
#  * Copyright 2011 - 2013 Tim Chien
#  * Released under the MIT license
#  */
# window.setImmediate||(window.setImmediate=function(){return window.msSetImmediate||window.webkitSetImmediate||window.mozSetImmediate||window.oSetImmediate||function(){if(!window.postMessage||!window.addEventListener)return null;var t=[void 0],e="zero-timeout-message",r=function(r){var n=t.length;return t.push(r),window.postMessage(e+n.toString(36),"*"),n};return window.addEventListener("message",function(r){if("string"==typeof r.data&&r.data.substr(0,e.length)===e){r.stopImmediatePropagation();var n=parseInt(r.data.substr(e.length),36);t[n]&&(t[n](),t[n]=void 0)}},!0),window.clearImmediate=function(e){t[e]&&(t[e]=void 0)},r}()||function(t){window.setTimeout(t,0)}}()),window.clearImmediate||(window.clearImmediate=function(){return window.msClearImmediate||window.webkitClearImmediate||window.mozClearImmediate||window.oClearImmediate||function(t){window.clearTimeout(t)}}()),function(r){var a=function(){var t=document.createElement("canvas");if(!t||!t.getContext)return!1;var e=t.getContext("2d");return!!e.getImageData&&(!!e.fillText&&(!!Array.prototype.some&&!!Array.prototype.push))}(),o=function(){if(a){for(var t,e,r=document.createElement("canvas").getContext("2d"),n=20;n;){if(r.font=n.toString(10)+"px sans-serif",r.measureText("Ｗ").width===t&&r.measureText("m").width===e)return n+1;t=r.measureText("Ｗ").width,e=r.measureText("m").width,n--}return 0}}(),s=function(t){for(var e,r,n=t.length;n;e=Math.floor(Math.random()*n),r=t[--n],t[n]=t[e],t[e]=r);return t},l=function(t,e){function r(t,e){return"hsl("+(360*Math.random()).toFixed()+","+(30*Math.random()+70).toFixed()+"%,"+(Math.random()*(e-t)+t).toFixed()+"%)"}if(a){Array.isArray(t)||(t=[t]),t.forEach(function(e,r){if("string"==typeof e){if(t[r]=document.getElementById(e),!t[r])throw"The element id specified is not found."}else if(!e.tagName&&!e.appendChild)throw"You must pass valid HTML elements, or ID of the element."});var n={list:[],fontFamily:'"Trebuchet MS", "Heiti TC", "微軟正黑體", "Arial Unicode MS", "Droid Fallback Sans", sans-serif',fontWeight:"normal",color:"random-dark",minSize:0,weightFactor:1,clearCanvas:!0,backgroundColor:"#fff",gridSize:8,drawOutOfBound:!1,origin:null,drawMask:!1,maskColor:"rgba(255,0,0,0.3)",maskGapWidth:.3,wait:0,abortThreshold:0,abort:function(){},minRotation:-Math.PI/2,maxRotation:Math.PI/2,rotationStep:.1,shuffle:!0,rotateRatio:.1,shape:"circle",ellipticity:.65,classes:null,hover:null,click:null};if(e)for(var i in e)i in n&&(n[i]=e[i]);if("function"!=typeof n.weightFactor){var l=n.weightFactor;n.weightFactor=function(t){return t*l}}if("function"!=typeof n.shape)switch(n.shape){case"circle":default:n.shape="circle";break;case"cardioid":n.shape=function(t){return 1-Math.sin(t)};break;case"diamond":case"square":n.shape=function(t){var e=t%(2*Math.PI/4);return 1/(Math.cos(e)+Math.sin(e))};break;case"triangle-forward":n.shape=function(t){var e=t%(2*Math.PI/3);return 1/(Math.cos(e)+Math.sqrt(3)*Math.sin(e))};break;case"triangle":case"triangle-upright":n.shape=function(t){var e=(t+3*Math.PI/2)%(2*Math.PI/3);return 1/(Math.cos(e)+Math.sqrt(3)*Math.sin(e))};break;case"pentagon":n.shape=function(t){var e=(t+.955)%(2*Math.PI/5);return 1/(Math.cos(e)+.726543*Math.sin(e))};break;case"star":n.shape=function(t){var e=(t+.955)%(2*Math.PI/10);return(t+.955)%(2*Math.PI/5)-2*Math.PI/10>=0?1/(Math.cos(2*Math.PI/10-e)+3.07768*Math.sin(2*Math.PI/10-e)):1/(Math.cos(e)+3.07768*Math.sin(e))}}n.gridSize=Math.max(Math.floor(n.gridSize),4);var h,u,c,f,d,g,p,v=n.gridSize,m=v-n.maskGapWidth,x=Math.abs(n.maxRotation-n.minRotation),y=Math.min(n.maxRotation,n.minRotation),w=n.rotationStep;switch(n.color){case"random-dark":p=function(){return r(10,50)};break;case"random-light":p=function(){return r(50,90)};break;default:"function"==typeof n.color&&(p=n.color)}var _=null;"function"==typeof n.classes&&(_=n.classes);var b,S=!1,M=[],T=function(t){var e,r,n=t.currentTarget,i=n.getBoundingClientRect();t.touches?(e=t.touches[0].clientX,r=t.touches[0].clientY):(e=t.clientX,r=t.clientY);va ...
# </script>
# 作者: wqw547243068@163.com, &lt;a href="https://github.com/wqw547243068/Python-learning/blob/master/data_mining/huawei.ipynb"&gt;代码地址&lt;/a&gt;</head>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !cp page_huawei.html "$dest_dir"

# %%
import os
#!ls /content/drive/My\ Drive
dest_dir = '/content/drive/My Drive/huawei'
os.listdir(dest_dir)
#os.chdir()
# Out:
# ['page_huawei.html']

# %%
# %%bash
# #git clone https://github.com/wqw547243068/Python-learning.git
# ls Python-learning/data_mining/
# Out:
# huawei.ipynb
# page_huawei.html

# %%
# %%bash
# cp page_huawei.html Python-learning/data_mining/
# cd Python-learning/data_mining/
# git config --global user.email "wqw547243068@163.com"
# git config --global user.name "wqw547243068"
# git add page_huawei.html
# git commit -m "增加华为分析结果"
# git push
# # !ls RenZhengfei/2016
# Out:
# [master c9c44e8] 增加华为分析结果
#  1 file changed, 23170 insertions(+)
#  create mode 100644 data_mining/page_huawei.html
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# ## 分词

# %%
import jieba

str='中国是世界上人口最多的国家，有悠久的文明和历史'
a=jieba.cut(str,cut_all=False)
print('/'.join(a))
# Out:
# 中国/是/世界/上/人口/最多/的/国家/，/有/悠久/的/文明/和/历史

# %%
import json
import jieba
from jieba import analyse

# (1)自定义字典
#jieba.load_userdict(file_name) # file_name 为文件类对象或自定义词典的路径
jieba.add_word('中国科学院计算所')
jieba.add_word('京都大学')
# (2)测试数据
text = u"一个傻子在北京,难受想哭很不开心啊"
text = u'小明硕士毕业于中国科学院计算所，后在日本京都大学深造,我来到北京清华大学堂'
#print(json.dumps(fool.cut(text),ensure_ascii=False))
# ['一个', '傻子', '在', '北京']
# (3)开始分词
#seg_list = jieba.cut(text)
seg_list = jieba.lcut(text)
#seg_list = jieba.cut(text, cut_all=True)
print("jieba分词: " + "/ ".join(seg_list))  # 精确模式
# (4)关键词提取
#res = jieba.analyse.TFIDF(text)
res = analyse.extract_tags(text)
print(u'TF-IDF关键词提取：'+json.dumps(res,ensure_ascii=False))
res = analyse.textrank(text)
print(u'TextRank关键词提取：'+json.dumps(res,ensure_ascii=False))
# Out:
# jieba分词: 小明/ 硕士/ 毕业/ 于/ 中国科学院计算所/ ，/ 后/ 在/ 日本京都大学/ 深造/ ,/ 我/ 来到/ 北京/ 清华大学/ 堂
# TF-IDF关键词提取：["日本京都大学", "中国科学院计算所", "小明", "深造", "硕士", "清华大学", "毕业", "来到", "北京"]
# TextRank关键词提取：["深造", "硕士", "来到", "毕业", "北京"]

# %%
import jieba
text = """我是一条天狗呀！
我把月来吞了，
我把日来吞了，
我把一切的星球来吞了，
我把全宇宙来吞了。
我便是我了！"""
sentences = text.split()
sent_words = [list(jieba.cut(sent0)) for sent0 in sentences]
document = [" ".join(sent0) for sent0 in sent_words]
print(document)
# ['我 是 一条 天狗 呀 ！', '我 把 月 来 吞 了 ，', '我 把 日来 吞 了 ，', '我 把 一切 的 星球 来 吞 了 ，', '我 把 全宇宙 来 吞 了 。', '我 便是 我 了 ！']
# Out:
# ['我 是 一条 天狗 呀 ！', '我 把 月 来 吞 了 ，', '我 把 日来 吞 了 ，', '我 把 一切 的 星球 来 吞 了 ，', '我 把 全宇宙 来 吞 了 。', '我 便是 我 了 ！']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_model = TfidfVectorizer().fit(document)
print(tfidf_model.vocabulary_)
# {'一条': 1, '天狗': 4, '日来': 5, '一切': 0, '星球': 6, '全宇宙': 3, '便是': 2}
sparse_result = tfidf_model.transform(document)
print(sparse_result)
# Out:
# {'一条': 1, '天狗': 4, '日来': 5, '一切': 0, '星球': 6, '全宇宙': 3, '便是': 2}
#   (0, 4)	0.7071067811865476
#   (0, 1)	0.7071067811865476
#   (2, 5)	1.0
#   (3, 6)	0.7071067811865476
#   (3, 0)	0.7071067811865476
#   (4, 3)	1.0
#   (5, 2)	1.0

# %% [markdown]
# ## 词向量训练
# - 挖掘文本背后的含义

# %% [markdown]
# ### word2vec词向量
# - 诞生于2013年，业界流行的语义向量训练方法

# %%
# 参考地址：http://www.52nlp.cn/%E4%B8%AD%E8%8B%B1%E6%96%87%E7%BB%B4%E5%9F%BA%E7%99%BE%E7%A7%91%E8%AF%AD%E6%96%99%E4%B8%8A%E7%9A%84word2vec%E5%AE%9E%E9%AA%8C
import logging  
import os  
import time  
  
import gensim  
from gensim.models import word2vec  
import jieba  
#import nltk 
import json
  
logging.basicConfig(format='%(asctime)s:%(levelname)s:%(message)s',level=logging.INFO)    
start1 = time.clock()   
input_file_name = u'E:/百度云/IT技术_new/编程语言/python/demo/word/result.txt' # 原始文件Unicode编码
input_file_f = open(input_file_name,'r')  
#contents = input_file_f.read() # 整个文件读到一个变量里
print '读取文件耗时：',time.clock()
#sentences = [i.strip().split(" ") for  i in contents[:10]]
sentences = []
print '转换后:\n','|'.join(['&'.join(i) for i in sentences])
# 开始逐行处理
for line in input_file_f.readlines(): 
    #按行读取 
    sentences.append(line.strip().split(" "))
#print '行数:%s,内容:\n'%(len(sentences)),json.dumps(sentences,ensure_ascii=False)
#sentences是句子序列，句子又是单词列表，比如，sentences = [['first', 'sentence'], ['second', 'sentence']]
model = word2vec.Word2Vec(sentences,min_count=2,size=200) #min_count表示小于该数的单词会被剔除，默认值为5;size表示神经网络的隐藏层单元数，默认为100
#保存生成的训练模型
output_model = u'E:/百度云/IT技术_new/编程语言/python/demo/word/model'
model.save(output_model)#加载模型文件new_model = gensim.models.Word2Vec.load('model/mymodel4')

# %%
#加载模型文件
new_model = gensim.models.Word2Vec.load(output_model)
dir(new_model) # 多种函数方法,
print new_model.vector_size # 词向量维度
print ','.join(new_model.index2word) # index2word保存单词
# 计算指定词的所以相似词
test_word = '经理'
similar_word_list = new_model.most_similar(test_word)
print json.dumps(similar_word_list,ensure_ascii=False)
#print json.dumps(similar_word_list,ensure_ascii=False,indent=4)
# 抽取北京的搜索session：select query_list from user_satisfy_query where dt=20160918 and province rlike '^010' and count > 1;
#print json.dumps(new_model.most_similar(u'天安门'),ensure_ascii=False)
#In [76]: print json.dumps(new_model.most_similar(u'旅店'),ensure_ascii=False)
#[["莫泰", 0.8472937345504761], ["易佰", 0.8139138221740723], ["168", 0.7009128928184509], ["连锁", 0.6979336738586426], ["旅馆", 0.6874777674674988], ["旺子成", 0.6520262360572815], ["快捷", 0.6426747441291809], ["家庭旅馆", 0.6317397356033325], ["人在旅途", 0.6164605021476746], ["寺易佰", 0.6112728714942932]]
#In [77]: print json.dumps(new_model.most_similar(u'菜馆'),ensure_ascii=False)
#[["家常菜", 0.8295753598213196], ["风味", 0.8144116401672363], ["正宗", 0.8008058071136475], ["菜", 0.787124514579773], ["饺子馆", 0.7830443382263184], ["刀削面", 0.7752013802528381], ["特色", 0.7629570364952087], ["面馆", 0.7591361403465271], ["面", 0.7421250939369202], ["农家菜", 0.7410575747489929]]
#In [158]: print json.dumps(new_model.most_similar(u'软件园'),ensure_ascii=False)  
#[["用友", 0.7017531991004944], ["金蝶", 0.6142528057098389], ["孵化器", 0.5947192907333374], ["网易", 0.5910834074020386], ["f11", 0.584527850151062], ["软件", 0.5816747546195984], ["租贷", 0.5489269495010376], ["卵", 0.5268262624740601], ["鲜花网", 0.5116425156593323], ["广联达", 0.507921576499939]]
#In [171]: print json.dumps(new_model.most_similar(u'美食'),ensure_ascii=False)
#[["中餐", 0.8337364196777344], ["川菜", 0.7456749677658081], ["快餐", 0.7315336465835571], ["西餐", 0.6596412658691406], ["自助餐", 0.6401817202568054], ["老姬", 0.6020432710647583], ["日本料理", 0.5849108099937439], ["合利屋", 0.5827316045761108], ["nokia", 0.5804284811019897], ["早点", 0.5785887241363525]]
#In [176]: print json.dumps(new_model.most_similar(u'麦当劳'),ensure_ascii=False)
#[["肯德基", 0.857654869556427], ["肯德鸡", 0.6457746028900146], ["KFC", 0.6434839963912964], ["kfc", 0.6308714151382446], ["街鼎", 0.6141167283058167], ["FSDT", 0.589178204536438], ["康得基", 0.5770742893218994], ["得来", 0.5747169852256775], ["十佛营", 0.5702893137931824], ["必胜客", 0.5698955655097961]]
print '（1）找某个词的相似词汇如下:\n词汇\t相似度\n','\n'.join(['%s\t%s'%(i[0],i[1]) for i in similar_word_list])
# 计算任意两个词的相似度
word_1 = '经理';word_2 = '数据'
print '（2）任意两个词汇的相似度(%s与%s)'%(word_1,word_2),new_model.similarity(word_1,word_2)
word_set_1 = ['经理','效率'];word_set_2 = ['数据','流程','重复']
print '（3）两个数据集间的余弦距离(%s)与(%s)：'%(json.dumps(word_set_1,ensure_ascii=False),json.dumps(word_set_1,ensure_ascii=False)),new_model.n_similarity(word_set_1, word_set_2) 
print '（4）找集合中不同的一项：(%s)'%(json.dumps(word_set_2,ensure_ascii=False)),new_model.doesnt_match(word_set_2)
# 独特的组合加减法
print json.dumps(new_model.most_similar(positive=[u'麦当劳'],negative=[u'肯德基',u'真功夫']),ensure_ascii=False)

# %% [markdown]
# ### BERT词向量
# - [如何用 Python 和 BERT 做中文文本二元分类？](https://www.jianshu.com/p/9b88d0cd9e8d)
# - ![](https://upload-images.jianshu.io/upload_images/64542-d90f0950c31be5ae.png)
# - ULMfit 和 BERT 都属于预训练语言模型（Pre-trained Language Modeling），具有很多的相似性

# %% [markdown]
# ## 贾跃亭
# - 参考：[我们文本分析了贾跃亭2017年全部公开信，发现他近期喜欢用“责任”“致歉”](https://mp.weixin.qq.com/s?__biz=MjM5MTQzNzU2NA==&mid=2651655947&idx=1&sn=b7f48e48b7505fd3b67c4a22e42cd1ad&chksm=bd4c28988a3ba18e365be4a852c8b870d0ca5539b36fb4a427b3ee420c79e8e89eaeaaec4261&mpshare=1&scene=23&srcid=0522kZpRnblIcs8MIWwrY4na#rd)

# %%
# 测试数据地址：https://wallstreetcn.com/articles/3523533
s="""
任何一个人都是在给定条件下来实现目标的。

本文由华商韬略原创， 作者：曹谨浩，首发于微信公众号：华商韬略（id：hstl8888）

创业二十载，贾跃亭的“伟大梦想”坑哭了投资者，纸糊的财务外皮终于罩不住扯到肾的扩张步伐。

4月26日，乐视网发布2018年报及关于暂停上市前的停牌公告，前者显示，公司净资产负30亿，后者则让乐视的退市进入倒计时。

4月29日，因涉嫌信息披露违法，证监会决定对贾跃亭进行立案调查。
王健林曾说：先定个小目标，挣他一个亿。一个亿不小，但对于企业经营者，要有远大理想，先在给定条件下，一步一步实现小目标，却是远大理想的必须路径。

路要一步步走，饭要一口口吃，步子大了容易扯着蛋，如果步子大太了不光扯着蛋，连心脏也会被扯掉。

如果贾跃亭可以现实一点，踏踏实实做视频、手机、电视，任何一样，他都已经卡到了不错的位置，也应该会有不错的前景。若能做成视频领先，手机领先，电视领先，甚至从中国领先做成世界领先，并且持续发展，就能够称得上是伟大了。
"""
import sys

#print(open('贾跃亭.txt', 'w'), s)

# %% [markdown]
# - NFM模型代码

# %%
"""
    NFM模型代码
"""
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer 
from sklearn.datasets import fetch_20newsgroups 
from sklearn.decomposition import NMF, LatentDirichletAllocation 

#data_file = 'C:/Users/wqw/Desktop/贾跃亭数据分析/贾跃亭数据分析/公开信时间整理.txt'
data_file = '贾跃亭.txt'
def display_topics(model, feature_names, no_top_words): 
    for topic_idx, topic in enumerate(model.components_): 
         print ("Topic %d:" % (topic_idx) )
         print (" ".join([feature_names[i]
         for i in topic.argsort()[:-no_top_words - 1:-1]]) )
        
dataset = open(data_file, encoding='utf-8').readlines()
documents = dataset
no_features = 1000
no_features = 100

#提取tf-idf特征
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english') 
tfidf = tfidf_vectorizer.fit_transform(documents) 
tfidf_feature_names = tfidf_vectorizer.get_feature_names() 

no_topics = ['乐视','资金', '变革', '生态', '布局', '硬件', '用户', '承诺', '责任','质疑', '债务', '歉意']
# 隐含语义向量维数
no_topics = 3
# NMF模型
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf) 

#top words数目
no_top_words = 15

# 显示
display_topics(nmf, tfidf_feature_names, no_top_words)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-79aac756d827> in <module>()
#      21 #提取tf-idf特征
#      22 tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
# ---> 23 tfidf = tfidf_vectorizer.fit_transform(documents)
#      24 tfidf_feature_names = tfidf_vectorizer.get_feature_names()
#      25
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1650         """
#    1651         self._check_params()
# -> 1652         X = super().fit_transform(raw_documents)
#    1653         self._tfidf.fit(X)
#    1654         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1056
#    1057         vocabulary, X = self._count_vocab(raw_documents,
# -> 1058                                           self.fixed_vocabulary_)
#    1059
#    1060         if self.binary:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     987             vocabulary = dict(vocabulary)
#     988             if not vocabulary:
# --> 989                 raise ValueError("empty vocabulary; perhaps the documents only"
#     990                                  " contain stop words")
#     991
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
pip install nltk
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install nltk
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more informations on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
# 绘制词汇分散图
import jieba
import re
import nltk

# Open the book
with open(data_file,encoding='utf-8') as t:
    text = [l.strip() for l in t]

# PLEASE STAY LOW!
text = [t.lower() for t in text][:-10]

# Remove 'chapter i' strings
regexp = re.compile(r'chapter \d')
text = [t for t in text if not re.match(regexp, t)]

# Raw text (one huge giant string)
raw = ' '.join(text)

# Here's the magic
tokens = [t for t in nltk.word_tokenize(raw) if t not in (',', '¡°', '¡±', '"')]
#tokens = [t for t in jieba.cut(raw) if t not in (',', '¡°', '¡±', '"')]

# (1) lexical_richness
distinct_tokens = set(tokens)
lexical_richness = len(distinct_tokens) / len(tokens)


from pylab import mpl 
mpl.rcParams['font.sans-serif'] = ['SimHei']
ntext = nltk.Text(tokens)
keyword_list = ['乐视','资金', '变革', '生态', '布局', '硬件', '用户', '承诺', '责任','质疑', '债务', '歉意']
ntext.dispersion_plot(keyword_list)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-a8d78addcccf> in <module>()
#       2 import jieba
#       3 import re
# ----> 4 import nltk
#       5
#       6 # Open the book
#
# ModuleNotFoundError: No module named 'nltk'

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
    词向量代码
"""
from gensim.models import word2vec,Phrases
from gensim.models.doc2vec import Doc2Vec,TaggedDocument,TaggedLineDocument
import logging
import warnings
from pprint import  pprint
import multiprocessing
warnings.filterwarnings("ignore")
cores = multiprocessing.cpu_count()

# ÑµÁ·Ö÷³ÌÐò
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
sentences =word2vec.Text8Corpus(data_file)  # ¼ÓÔØÓïÁÏ
model = word2vec.Word2Vec(sentences,sg=0, min_count=10,size=100,seed=1,workers=cores,window=5)  # ÑµÁ·skip-gramÄ£ÐÍ; Ä¬ÈÏwindow=5

#ÔÚÑµÁ·ÓïÁÏÖÐ£¬Ñ°ÕÒÓë¼ÖÔ¾Í¤Ïà¹ØµÄ¹ØÁª´Ê
model.wv.most_similar(['责任'],topn=15)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-b8ee8ec4b685> in <module>()
#       4     词向量代码
#       5 """
# ----> 6 from gensim.models import word2vec,Phrases
#       7 from gensim.models.doc2vec import Doc2Vec,TaggedDocument,TaggedLineDocument
#       8 import logging
#
# ModuleNotFoundError: No module named 'gensim'
